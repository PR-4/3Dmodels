# %%
# Dependencies
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gempy.assets import topology as tp

import warnings

warnings.filterwarnings("ignore")

# Creating model object and indicating path
data_path = "../../../../input/BES/interpreted_seismics_2/processed/"
geo_model = gp.create_model("v1_500m_not_scaled")

# %%
# Loading model, the extension, the resolution and importing the data
gp.init_data(
    geo_model,
    extent=[431215.754, 474015.754, 7785829.449, 7795029.449, -7000, -2000],
    resolution=[50, 50, 50],
    path_i=data_path + "sp_500m_not_scaled.csv",
    path_o=data_path + "op_top_mid_base_500m_not_scaled.csv",
)
# Out:
# Active grids: ['regular']
# v1_500m_not_scaled  2024-03-15 12:05

# %%
geo_model.get_data()
# Out:
#                               X            Y        Z    smooth surface
# surface_points 0     431215.754  7785829.449 -2905.49  0.000002     top  \
#                1     431515.754  7785829.449 -2925.77  0.000002     top
#                2     432015.754  7785829.449 -2965.06  0.000002     top
#                3     432515.754  7785829.449 -3004.24  0.000002     top
#                4     433015.754  7785829.449 -3043.23  0.000002     top
# ...                         ...          ...      ...       ...     ...
#                5218  473515.754  7795029.449 -6050.33  0.000002    base
#                5219  474015.754  7795029.449 -6071.88  0.000002    base
# orientations   0     431215.754  7785829.450 -2905.49  0.010000     top
#                1     431215.754  7785829.450 -3551.43  0.010000     mid
#                2     431215.754  7785829.450 -4197.37  0.010000    base
#
#                               G_x           G_y  G_z
# surface_points 0              NaN           NaN  NaN
#                1              NaN           NaN  NaN
#                2              NaN           NaN  NaN
#                3              NaN           NaN  NaN
#                4              NaN           NaN  NaN
# ...                           ...           ...  ...
#                5218           NaN           NaN  NaN
#                5219           NaN           NaN  NaN
# orientations   0     1.000000e-12  1.000000e-12  1.0
#                1     1.000000e-12  1.000000e-12  1.0
#                2     1.000000e-12  1.000000e-12  1.0
#
# [5223 rows x 8 columns]

# %%
# Ordenando as surfaces (Estratigrafia (topo para base)) 3
gp.map_stack_to_surfaces(
    geo_model,
    {
        "Strat": ("top"),
        "Strat_2": ("mid"),
        "Strat_3": ("base"),
        "Basement": ("basement",),
    },
)
# Out:
#     surface    series  order_surfaces    color  id
# 0       top     Strat               1  #015482   1
# 1       mid   Strat_2               1  #9f0052   2
# 2      base   Strat_3               1  #ffbe00   3
# 3  basement  Basement               1  #728f02   4

# %%
# Seção transversal do modelo
gp.plot_2d(
    geo_model, direction="y", show_data=True, show_lith=True, ve=10, legend=False
)
gp.plot_2d(
    geo_model, direction="x", show_data=True, show_lith=True, ve=10, legend=False
)
# gp.plot_2d(geo_model, direction="z", show_data=True, show_lith=True, ve=1, legend=False)

# Ver os dados em 3D
gpv = gp.plot_3d(
    geo_model,
    plotter_type="background",
    show_data=True,
    ve=2,
)

# %%
# Interpolating and computing the model

gp.set_interpolator(
    geo_model,
    output=["geology"],
    compile_theano=True,
    theano_optimizer="fast_compile",  # fast_compile, fast_run
    dtype="float64",  # for model stability
)

sol = gp.compute_model(geo_model, compute_mesh=False)
# Out:
# Setting kriging parameters to their default values.
# Compiling aesara function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                            values
# range               44062.228723
# $C_o$            46225714.285714
# drift equations     [3, 3, 3, 3]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 11
#       1 # Interpolating and computing the model
#       3 gp.set_interpolator(
#       4     geo_model,
#       5     output=["geology"],
#    (...)
#       8     dtype="float64",  # for model stability
#       9 )
# ---> 11 sol = gp.compute_model(geo_model, compute_mesh=False)
#
# File c:\Users\beche\anaconda3\envs\gemgis\lib\site-packages\gempy\gempy_api.py:305, in compute_model(model, output, at, compute_mesh, reset_weights, reset_scalar, reset_block, sort_surfaces, debug, set_solutions, **kwargs)
#     298 model.solutions.set_solutions(
#     299     sol,
#     300     compute_mesh,
#     301     sort_surfaces,
#     302     **kwargs)
#     304 if sort_surfaces:
# --> 305     model.set_surface_order_from_solution()
#     306 return model.solutions
#
# File c:\Users\beche\anaconda3\envs\gemgis\lib\site-packages\gempy\core\model.py:1586, in ImplicitCoKriging.set_surface_order_from_solution(self)
#    1584 self._sfai_order_0 = sfai_order
#    1585 sel = self._surfaces.df['isActive'] & ~self._surfaces.df['isBasement']
# -> 1586 self._surfaces.df.loc[sel, 'sfai'] = sfai_order
#    1587 self._surfaces.df.sort_values(by=['series', 'sfai'], inplace=True,
#    1588                               ascending=False)
#    1589 self._surfaces.reset_order_surfaces()
#
# File c:\Users\beche\anaconda3\envs\gemgis\lib\site-packages\pandas\core\indexing.py:849, in _LocationIndexer.__setitem__(self, key, value)
#     846 self._has_valid_setitem_indexer(key)
#     848 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 849 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\beche\anaconda3\envs\gemgis\lib\site-packages\pandas\core\indexing.py:1828, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1825 # align and set the values
#    1826 if take_split_path:
#    1827     # We have to operate column-wise
# -> 1828     self._setitem_with_indexer_split_path(indexer, value, name)
#    1829 else:
#    1830     self._setitem_single_block(indexer, value, name)
#
# File c:\Users\beche\anaconda3\envs\gemgis\lib\site-packages\pandas\core\indexing.py:1884, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1879     if len(value) == 1 and not is_integer(info_axis):
#    1880         # This is a case like df.iloc[:3, [1]] = [0]
#    1881         #  where we treat as df.iloc[:3, 1] = 0
#    1882         return self._setitem_with_indexer((pi, info_axis[0]), value[0])
# -> 1884     raise ValueError(
#    1885         "Must have equal len keys and value "
#    1886         "when setting with an iterable"
#    1887     )
#    1889 elif lplane_indexer == 0 and len(value) == len(self.obj.index):
#    1890     # We get here in one case via .loc with a all-False mask
#    1891     pass
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
# Ploting 2D and 3D

# Seção transversal do modelo
gp.plot_2d(geo_model,direction="y",show_data=False,show_lith=True,ve=10)
gp.plot_2d(geo_model,direction="x",show_data=False,show_lith=True,ve=10,legend=True)

# %%
gpv = gp.plot_3d(geo_model, image=False, plotter_type="background", show_data=False, ve=5)

# %%
geo_model.solutions

# %%
# Salvar o modelo gerado em zip (contem todos os files relevantes para refazer o modelo)
gp.save_model(
    geo_model,
    compress=False,
    solution=True,
)
