# %%
# Dependencies
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gempy.assets import topology as tp

import warnings

warnings.filterwarnings("ignore")

pd.set_option("display.precision", 2)

# Creating model object and indicating path
data_path = "../../../../../input/BES/interpreted_seismics_2/surfaces_final/teste_1/"
nome_modelo = "BES-Seismics-Horizontes-Luis_Teste-1"
geo_model = gp.create_model(nome_modelo)
# Out:
# No module named 'osgeo'

# %% [markdown]
# ### Detalhes dos dados
# - Contém os surfaces interpolados pelo Petrel a partir de interpretação sismica
# - Todos os surfaces foram reduzidos em X e Y para diminuir a quantidade de pontos (1000). De 386mil pontos para 1453. Quanto mais ponto, mais memoria usa.
# - Cada horizonte (surface no GemPy) é uma série
# - Ponto de orientação gerado com KNN pelo GemPy (Quando salvar a orientação gerada, precisa trocar o header surfaces para formation, se for abrir o .csv ao invés de rodar sempre o KNN)

# %% [markdown]
# ## Step by step

# %%
# Loading model, the extension, the resolution and importing the data
gp.init_data(
    geo_model,
    extent=[431215.754, 474015.754, 7785829.449, 7795029.449, -6544.67, -2466.97],
    resolution=[20, 20, 20],
    path_i=data_path + "sp_1000m_not_scaled.csv",
    path_o=data_path + "orientations_points_2.csv",
)
# Out:
# Active grids: ['regular']
# BES-Seismics-Horizontes-Luis_Teste-1  2024-04-26 13:15

# %%
gp.get_data(
    geo_model,
    "surfaces",
)
# Out:
#     surface          series  order_surfaces    color  id
# 0       top  Default series               1  #015482   1
# 1       mid  Default series               2  #9f0052   2
# 2      base  Default series               3  #ffbe00   3
# 3  basement        Basement               1  #728f02   4

# %%
# Ordenando as surfaces (Estratigrafia (topo para base)) 1
gp.map_stack_to_surfaces(
    geo_model,
    {
        "Strat_Series_1": ("top",),
        "Strat_Series_2": ("mid",),
        "Strat_Series_3": ("base",),
        "Basement_series": ("basement",),
    },
)
# Out:
#     surface           series  order_surfaces    color  id
# 0       top   Strat_Series_1               1  #015482   1
# 1       mid   Strat_Series_2               1  #9f0052   2
# 2      base   Strat_Series_3               1  #ffbe00   3
# 3  basement  Basement_series               1  #728f02   4

# %%
geo_model.series
# Out:
#                  order_series BottomRelation  isActive  isFault  isFinite
# Strat_Series_1              1        Erosion      True    False     False
# Strat_Series_2              2        Erosion      True    False     False
# Strat_Series_3              3        Erosion      True    False     False
# Basement_series             4        Erosion     False    False     False

# %%
geo_model.get_data()
# Out:
#                              X         Y        Z    smooth surface   G_x
# surface_points 0     431215.75  7.79e+06 -2905.49  2.00e-06     top   NaN  \
#                1     432015.75  7.79e+06 -2965.06  2.00e-06     top   NaN
#                2     433015.75  7.79e+06 -3043.23  2.00e-06     top   NaN
#                3     434015.75  7.79e+06 -3120.30  2.00e-06     top   NaN
#                4     435015.75  7.79e+06 -3195.17  2.00e-06     top   NaN
# ...                        ...       ...      ...       ...     ...   ...
# orientations   1447  470015.75  7.80e+06 -5884.08  1.00e-02    base  0.05
#                1448  471015.75  7.80e+06 -5936.45  1.00e-02    base  0.05
#                1449  472015.75  7.80e+06 -5983.97  1.00e-02    base  0.05
#                1450  473015.75  7.80e+06 -6028.57  1.00e-02    base  0.05
#                1451  474015.75  7.80e+06 -6071.88  1.00e-02    base  0.05
#
#                           G_y  G_z
# surface_points 0          NaN  NaN
#                1          NaN  NaN
#                2          NaN  NaN
#                3          NaN  NaN
#                4          NaN  NaN
# ...                       ...  ...
# orientations   1447 -1.32e-03  1.0
#                1448 -1.10e-04  1.0
#                1449 -8.35e-04  1.0
#                1450 -1.69e-03  1.0
#                1451 -3.13e-03  1.0
#
# [2904 rows x 8 columns]

# %% [markdown]
# - Precisar criar os pontos de orientação com o código abaixo

# %%
neighbours = gp.select_nearest_surfaces_points(geo_model, geo_model.surface_points.df, 10)
opoints = gp.set_orientation_from_neighbours_all(geo_model, neighbours)

# %%
geo_model.get_data()
# Out:
#                             X         Y        Z    smooth surface   G_x
# surface_points 0    431215.75  7.79e+06 -2905.49  2.00e-06     top   NaN  \
#                1    432015.75  7.79e+06 -2965.06  2.00e-06     top   NaN
#                2    433015.75  7.79e+06 -3043.23  2.00e-06     top   NaN
#                3    434015.75  7.79e+06 -3120.30  2.00e-06     top   NaN
#                4    435015.75  7.79e+06 -3195.17  2.00e-06     top   NaN
# ...                       ...       ...      ...       ...     ...   ...
# orientations   479  470015.75  7.80e+06 -5884.08  1.00e-02    base  0.05
#                480  471015.75  7.80e+06 -5936.45  1.00e-02    base  0.05
#                481  472015.75  7.80e+06 -5983.97  1.00e-02    base  0.05
#                482  473015.75  7.80e+06 -6028.57  1.00e-02    base  0.05
#                483  474015.75  7.80e+06 -6071.88  1.00e-02    base  0.05
#
#                          G_y  G_z
# surface_points 0         NaN  NaN
#                1         NaN  NaN
#                2         NaN  NaN
#                3         NaN  NaN
#                4         NaN  NaN
# ...                      ...  ...
# orientations   479 -1.32e-03  1.0
#                480 -1.10e-04  1.0
#                481 -8.35e-04  1.0
#                482 -1.69e-03  1.0
#                483 -3.13e-03  1.0
#
# [2904 rows x 8 columns]

# %%
# Salvando os pontos de orientação gerados pelo KNN (K=10)
orientations_p = geo_model.orientations.df
orientations_p.to_csv(data_path + "orientations_points.csv")
orientations_p
# Out:
#              X         Y        Z   X_c   Y_c   Z_c   G_x       G_y  G_z
# 968  431215.75  7.79e+06 -2905.49  0.25  0.45  0.52  0.08 -1.78e-02  1.0  \
# 969  432015.75  7.79e+06 -2965.06  0.26  0.45  0.52  0.08 -1.74e-02  1.0
# 970  433015.75  7.79e+06 -3043.23  0.27  0.45  0.52  0.08 -1.72e-02  1.0
# 971  434015.75  7.79e+06 -3120.30  0.28  0.45  0.52  0.08 -1.50e-02  1.0
# 972  435015.75  7.79e+06 -3195.17  0.29  0.45  0.51  0.07 -1.35e-02  1.0
# ..         ...       ...      ...   ...   ...   ...   ...       ...  ...
# 479  470015.75  7.80e+06 -5884.08  0.70  0.55  0.48  0.05 -1.32e-03  1.0
# 480  471015.75  7.80e+06 -5936.45  0.72  0.55  0.48  0.05 -1.10e-04  1.0
# 481  472015.75  7.80e+06 -5983.97  0.73  0.55  0.48  0.05 -8.35e-04  1.0
# 482  473015.75  7.80e+06 -6028.57  0.74  0.55  0.48  0.05 -1.69e-03  1.0
# 483  474015.75  7.80e+06 -6071.88  0.75  0.55  0.48  0.05 -3.13e-03  1.0
#
#       dip  azimuth  polarity surface          series   id  order_series
# 968  4.51   103.05       1.0     top  Strat_Series_1  1.0           1.0  \
# 969  4.51   102.79       1.0     top  Strat_Series_1  1.0           1.0
# 970  4.52   102.58       1.0     top  Strat_Series_1  1.0           1.0
# 971  4.42   101.27       1.0     top  Strat_Series_1  1.0           1.0
# 972  4.23   100.51       1.0     top  Strat_Series_1  1.0           1.0
# ..    ...      ...       ...     ...             ...  ...           ...
# 479  3.14    91.38       1.0    base  Strat_Series_3  3.0           3.0
# 480  2.89    90.12       1.0    base  Strat_Series_3  3.0           3.0
# 481  2.72    91.01       1.0    base  Strat_Series_3  3.0           3.0
# 482  2.69    92.06       1.0    base  Strat_Series_3  3.0           3.0
# 483  2.67    93.85       1.0    base  Strat_Series_3  3.0           3.0
#
#      smooth
# 968    0.01
# 969    0.01
# 970    0.01
# 971    0.01
# 972    0.01
# ..      ...
# 479    0.01
# 480    0.01
# 481    0.01
# 482    0.01
# 483    0.01
#
# [1452 rows x 17 columns]

# %%
# Trocando o nome de surface para formation (necessário se for importar no Gempy)
orientations_p_formation = orientations_p.copy()
orientations_p_formation = orientations_p_formation.rename(columns={'surface': 'formation'})
orientations_p_formation.to_csv(data_path + "orientations_points_2.csv")
orientations_p_formation
# Out:
#              X         Y        Z   X_c   Y_c   Z_c   G_x       G_y  G_z
# 968  431215.75  7.79e+06 -2905.49  0.25  0.45  0.52  0.08 -1.78e-02  1.0  \
# 969  432015.75  7.79e+06 -2965.06  0.26  0.45  0.52  0.08 -1.74e-02  1.0
# 970  433015.75  7.79e+06 -3043.23  0.27  0.45  0.52  0.08 -1.72e-02  1.0
# 971  434015.75  7.79e+06 -3120.30  0.28  0.45  0.52  0.08 -1.50e-02  1.0
# 972  435015.75  7.79e+06 -3195.17  0.29  0.45  0.51  0.07 -1.35e-02  1.0
# ..         ...       ...      ...   ...   ...   ...   ...       ...  ...
# 479  470015.75  7.80e+06 -5884.08  0.70  0.55  0.48  0.05 -1.32e-03  1.0
# 480  471015.75  7.80e+06 -5936.45  0.72  0.55  0.48  0.05 -1.10e-04  1.0
# 481  472015.75  7.80e+06 -5983.97  0.73  0.55  0.48  0.05 -8.35e-04  1.0
# 482  473015.75  7.80e+06 -6028.57  0.74  0.55  0.48  0.05 -1.69e-03  1.0
# 483  474015.75  7.80e+06 -6071.88  0.75  0.55  0.48  0.05 -3.13e-03  1.0
#
#       dip  azimuth  polarity formation          series   id  order_series
# 968  4.51   103.05       1.0       top  Strat_Series_1  1.0           1.0  \
# 969  4.51   102.79       1.0       top  Strat_Series_1  1.0           1.0
# 970  4.52   102.58       1.0       top  Strat_Series_1  1.0           1.0
# 971  4.42   101.27       1.0       top  Strat_Series_1  1.0           1.0
# 972  4.23   100.51       1.0       top  Strat_Series_1  1.0           1.0
# ..    ...      ...       ...       ...             ...  ...           ...
# 479  3.14    91.38       1.0      base  Strat_Series_3  3.0           3.0
# 480  2.89    90.12       1.0      base  Strat_Series_3  3.0           3.0
# 481  2.72    91.01       1.0      base  Strat_Series_3  3.0           3.0
# 482  2.69    92.06       1.0      base  Strat_Series_3  3.0           3.0
# 483  2.67    93.85       1.0      base  Strat_Series_3  3.0           3.0
#
#      smooth
# 968    0.01
# 969    0.01
# 970    0.01
# 971    0.01
# 972    0.01
# ..      ...
# 479    0.01
# 480    0.01
# 481    0.01
# 482    0.01
# 483    0.01
#
# [1452 rows x 17 columns]

# %%
# Seção transversal do modelo
gp.plot_2d(geo_model, direction="y", show_data=True, show_lith=True, ve=5, legend=False)
gp.plot_2d(geo_model, direction="x", show_data=True, show_lith=True, ve=5, legend=False)
# gp.plot_2d(geo_model, direction="z", show_data=True, show_lith=True, ve=1, legend=False)

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(
    geo_model,
    plotter_type="background",
    image=False,
    show_data=True,
    show_surfaces=True,
    show_scalar=True,
    show_boundaries=True,
    ve=5,
)

# %%
# %%time
gp.set_interpolator(
    geo_model, 
    output=['geology'], 
    compile_theano=True, 
    theano_optimizer='fast_run', # fast_compile, fast_run
    dtype="float64",  # for model stability
    verbose=[]
)
# Out:
# Setting kriging parameters to their default values.
# Compiling aesara function...

# %%
geo_model.update_to_interpolator()
# Out:
# True

# %%
# %%time
gp.compute_model(
    geo_model, 
    compute_mesh=True,
    )
# Out:
# CPU times: total: 8min 22s
# Wall time: 8min 22s
# Lithology ids
#   [4. 4. 4. ... 1. 1. 1.]

# %%
# Seção transversal do modelo
gp.plot_2d(
    geo_model,
    direction="y",
    show_data=False,
    show_lith=True,
    ve=5,
)
gp.plot_2d(
    geo_model,
    direction="x",
    show_data=False,
    show_lith=True,
    ve=5,
    legend=True,
)

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(geo_model, image=False, plotter_type="background", show_data=False, ve=5)

# %%
topo_init = tp.compute_topology(
    geo_model, direction="x", voxel_threshold=1
)  # , direction="Y", cell_number=15)
edges_init, centroids_init = tp.clean_unconformity_topology(
    geo_model, 1, topo_init[0], topo_init[1]
)

# %%
# Seção transversal do modelo
gp.plot_2d(
    geo_model,
    direction="y",
    show_data=False,
    show_lith=True,
    ve=5,
)
gp.plot.plot_topology(geo_model, edges_init, centroids_init)

# %% [markdown]
# - Salvando pelo GemPy e em pickle

# %%
# Salvar o modelo gerado em zip (contem todos os files relevantes para refazer o modelo)
gp.save_model(
    geo_model,
    compress=True,
)
# Out:
# True

# %%
import pickle
import datetime
model_name = "BES-Seismics-Horizontes-Luis_Teste-1"
resolution = [50, 50, 50]
date_t = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
fn = f"{model_name}_{resolution[0]}x_{resolution[1]}y_{resolution[2]}z_{date_t}.pkl"
save_path = "../../../../../output/BES/interpreted_seismics_2/surfaces_final/teste_1/res100x100x100/"
full_path = save_path + fn
print(full_path)
# Out:
# ../../../../../output/BES/interpreted_seismics_2/surfaces_final/teste_1/res100x100x100/BES-Seismics-Horizontes-Luis_Teste-1_50x_50y_50z_2024-04-08-17-19-32.pkl

# %%
import os

# Get the absolute path
absolute_path = os.path.abspath(full_path)

print(absolute_path)
# Out:
# c:\Users\BernardoPR4\Documents\GitHub\3Dmodels\output\BES\interpreted_seismics_2\surfaces_final\teste_1\res100x100x100\BES-Seismics-Horizontes-Luis_Teste-1_50x_50y_50z_2024-04-08-17-19-32.pkl

# %%
import pickle
import datetime
save_path = "../../../../../output/BES/interpreted_seismics_2/surfaces_final/teste_1/res100x100x100/BES-Seismics-Horizontes-Luis_Teste-1"
with open(save_path, "wb") as f:
    pickle.dump(geo_model, f)
