# %%
# Importar dependências
import gempy as gp
import gempy_viewer as gpv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import warnings

warnings.filterwarnings("ignore")

# Creating model object and indicating path
data_path = "../../../../../3Dmodels/input/BES/interpreted_seismics_2/GemPy 3.0/"
# Out:
# Setting Backend To: AvailableBackends.numpy

# %% [markdown]
# ## Step by step

# %%
geo_model: gp.data.GeoModel = gp.create_geomodel(
    project_name="Modelo_1",
    extent=[425000, 480000, 7780000, 7800000, -7000, -2000],
    resolution=[50, 50, 50],
    importer_helper=gp.data.ImporterHelper(
        path_to_surface_points=data_path + "surface_points_1500m_rescaled.csv",
        path_to_orientations=data_path + "orientations_points_1000m.csv",
    ),
)

# %%
#geo_model.structural_frame

# %%
gp.map_stack_to_surfaces(
    gempy_model=geo_model,
    mapping_object=  # TODO: This mapping I do not like it too much. We should be able to do it passing the data objects directly
    {
        "Strat": ("MAASTRICHTIANO", "CENOMANIANO"),
        "Basement": ("basement",),
    },
)

#geo_model.structural_frame
# Out:
# Could not find element 'basement' in any group.
# StructuralFrame(
# 	structural_groups=[
# StructuralGroup(
# 	name=Strat,
# 	structural_relation=StackRelationType.ERODE,
# 	elements=[
# Element(
# 	name=MAASTRICHTIANO,
# 	color=#9f0052,
# 	is_active=True
# ),
# Element(
# 	name=CENOMANIANO,
# 	color=#015482,
# 	is_active=True
# )
# ]
# )
# ],
# 	fault_relations=
# [[False]],

# %%
#geo_model.grid

# %%
gpv.plot_2d(geo_model, direction="y", show_data=True, show_lith=False, ve=5, legend=True)
gpv.plot_2d(geo_model, direction="x", show_data=True, show_lith=False, ve=5, legend=True)

# %%
gempy_vista_model = gpv.plot_3d(
    geo_model,
    plotter_type="basic",  # Use 'notebook' instead of 'basic'
    ve=5,
    show_values=False,
    show_block=True,
    show=False  # This prevents the plot from being shown immediately
)

# 
plotter = gempy_vista_model.p

# Adiciona uma luz
#plotter.enable_eye_dome_lighting()

# Customize the plot
#plotter.show_grid(all_edges=False)
plotter.show_bounds(font_size=6, location="furthest") # show_xaxis=False, show_yaxis=False, show_zaxis=Falsehttps://docs.pyvista.org/version/stable/api/plotting/_autosummary/pyvista.renderer.show_bounds#pyvista.Renderer.show_bounds
#plotter.add_text("BES", position=(500, 700, 1000), font_size=20)
plotter.set_background("white")
#plotter.border_color = "black" 

# Show the plot
plotter.show()

# %%
"""gempy_vista_premodel = gpv.plot_3d(
    geo_model,
    plotter_type="basic",  # Use 'notebook' instead of 'basic'
    active_scalar_field=None,
    ve=5,
    show_data=True,
    show_results=True,
    show_surfaces=False,
    show_lith=True,
    show_scalar=True,
    show_boundaries=True,
    show_topography=False,
    show_section_trace=True,
    show_values=True,
    show_block=False,
    show=True  # This prevents the plot from being shown immediately
)

# 
plotter = gempy_vista_premodel.p

# Adiciona uma luz
#plotter.enable_eye_dome_lighting()

# Customize the plot
plotter.show_grid()
#plotter.add_text("BES", position=(500, 700, 1000), font_size=20)
plotter.set_background("white")
plotter.border_color = "black" 

# Show the plot
plotter.show"""
# Out:
# <bound method Plotter.show of <pyvista.plotting.plotter.Plotter object at 0x000001EE71054AC0>>

# %%
"""bounds = [0.0, 179000.0, 0.0, 148000.0, -20000, 500]

# Calculate midpoints
mid_x = (bounds[0] + bounds[1]) / 2
mid_y = (bounds[2] + bounds[3]) / 2

# Set section grid
gp.set_section_grid(
    grid=geo_model.grid,
    section_dict={
        'section1': ([bounds[0], mid_y], [bounds[1], mid_y], [200, 150])
    }
)"""
# Out:
# "bounds = [0.0, 179000.0, 0.0, 148000.0, -20000, 500]\n\n# Calculate midpoints\nmid_x = (bounds[0] + bounds[1]) / 2\nmid_y = (bounds[2] + bounds[3]) / 2\n\n# Set section grid\ngp.set_section_grid(\n    grid=geo_model.grid,\n    section_dict={\n        'section1': ([bounds[0], mid_y], [bounds[1], mid_y], [200, 150])\n    }\n)"

# %%
#gpv.plot_section_traces(geo_model)

# %%
#bes_series = geo_model.structural_frame.get_group_by_name("Strat_Series")

# %%
"""gp.modify_surface_points(
    geo_model=geo_model,
    elements_names=["bes_89", "bes_90", "bes_91", "bes_92", "bes_93", "bes_94", "bes_95", "bes_96", "bes_97", "bes_98", "bes_99", "bes_100"],
    nugget=0.01
)"""
# Out:
# 'gp.modify_surface_points(\n    geo_model=geo_model,\n    elements_names=["bes_89", "bes_90", "bes_91", "bes_92", "bes_93", "bes_94", "bes_95", "bes_96", "bes_97", "bes_98", "bes_99", "bes_100"],\n    nugget=0.01\n)'

# %%
#geo_model.interpolation_options

# %%
"""geo_model.interpolation_options.number_octree_levels = 5
geo_model.interpolation_options.number_octree_levels_surface = 4
geo_model.interpolation_options.kernel_options.range = .8"""
# Out:
# 'geo_model.interpolation_options.number_octree_levels = 5\ngeo_model.interpolation_options.number_octree_levels_surface = 4\ngeo_model.interpolation_options.kernel_options.range = .8'

# %%
#print(geo_model.structural_frame)

# %%
model = gp.compute_model(
    geo_model)
# Out:
# Setting Backend To: AvailableBackends.numpy
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model = gp.compute_model(
#       2     geo_model)
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy\API\compute_API.py:48, in compute_model(gempy_model, engine_config)
#      45     interpolation_input = gempy_model.interpolation_input
#      46     gempy_model.taped_interpolation_input = interpolation_input
# ---> 48     gempy_model.solutions = gempy_engine.compute_model(
#      49         interpolation_input=interpolation_input,
#      50         options=gempy_model.interpolation_options,
#      51         data_descriptor=gempy_model.input_data_descriptor,
#      52         geophysics_input=gempy_model.geophysics_input,
#      53     )
#      55 case AvailableBackends.aesara | AvailableBackends.legacy:
#      56     gempy_model.legacy_model = _legacy_compute_model(gempy_model)
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\model\model_api.py:31, in compute_model(interpolation_input, options, data_descriptor, geophysics_input)
#      28 if BackendTensor.engine_backend is not AvailableBackends.PYTORCH and COMPUTE_GRADIENTS is False:
#      29     interpolation_input = copy.deepcopy(interpolation_input)
# ---> 31 output: list[OctreeLevel] = interpolate_n_octree_levels(
#      32     interpolation_input=interpolation_input,
#      33     options=options,
#      34     data_descriptor=data_descriptor
#      35 )
#      37 # region Geophysics
#      38 # ---------------------
#      39
#      40 # TODO: [ ] Gravity
#      41
#      42 # TODO: [ ] Magnetics
#      44 if geophysics_input is not None:
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\interp_features.py:33, in interpolate_n_octree_levels(interpolation_input, options, data_descriptor)
#      30 options.current_octree_level = i
#      32 # * Here it goes all the different grids
# ---> 33 next_octree: OctreeLevel = interpolate_on_octree(interpolation_input, options, data_descriptor)
#      35 if options.is_last_octree_level is False:
#      36     # * This is only a Grid with a Regular grid
#      37     grid_1_centers: Grid = get_next_octree_grid(
#      38         prev_octree=next_octree,
#      39         compute_topology=False,
#      40         debug=False
#      41     )
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_octree_generation.py:28, in interpolate_on_octree(interpolation_input, options, data_shape)
#      25     temp_interpolation_input = interpolation_input
#      27 # * Interpolate - centers
# ---> 28 output_0_centers: List[InterpOutput] = interpolate_all_fields(temp_interpolation_input, options, data_shape)  # interpolate - centers
#      30 # * Interpolate - corners
#      31 grid_0_centers: Grid = temp_interpolation_input.grid  # ? This could be moved to the next section
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_multi_scalar_field_manager.py:28, in interpolate_all_fields(interpolation_input, options, data_descriptor)
#      24 def interpolate_all_fields(interpolation_input: InterpolationInput, options: InterpolationOptions,
#      25                            data_descriptor: InputDataDescriptor) -> List[InterpOutput]:
#      26     """Interpolate all scalar fields given a xyz array of points"""
# ---> 28     all_scalar_fields_outputs: List[ScalarFieldOutput] = _interpolate_stack(data_descriptor, interpolation_input, options)
#      30     combined_scalar_output: List[CombinedScalarFieldsOutput] = _combine_scalar_fields(
#      31         all_scalar_fields_outputs = all_scalar_fields_outputs,
#      32         lithology_mask            = _lithology_mask(all_scalar_fields_outputs, data_descriptor.stack_relation),
#      33         faults_mask               = _faults_mask(all_scalar_fields_outputs, data_descriptor.stack_relation),
#      34         compute_scalar_grad       = options.compute_scalar_gradient
#      35     )
#      37     all_outputs = []
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_multi_scalar_field_manager.py:84, in _interpolate_stack(root_data_descriptor, root_interpolation_input, options)
#      81         interpolation_input_i.fault_values = fault_input
#      83         solver_input = input_preprocess(tensor_struct_i, interpolation_input_i)
# ---> 84         output: ScalarFieldOutput = interpolate_feature(
#      85             interpolation_input    = interpolation_input_i,
#      86             options                = options,
#      87             data_shape             = tensor_struct_i,
#      88             solver_input           = solver_input,
#      89             external_interp_funct  = stack_structure.interp_function,
#      90             external_segment_funct = stack_structure.segmentation_function
#      91         )
#      93 # @on
#      94         all_scalar_fields_outputs[i] = output
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_interp_single_feature.py:38, in interpolate_feature(interpolation_input, options, data_shape, solver_input, external_interp_funct, external_segment_funct, clean_buffer)
#      35 xyz = solver_input.xyz_to_interpolate
#      37 if external_interp_funct is None:  # * EXTERNAL INTERPOLATION FUNCTION branching
# ---> 38     weights, exported_fields = interpolate_scalar_field(solver_input, options)
#      40     exported_fields.set_structure_values(
#      41         reference_sp_position = data_shape.reference_sp_position,
#      42         slice_feature         = interpolation_input.slice_feature,
#      43         grid_size             = interpolation_input.grid.len_all_grids
#      44     )
#      46     exported_fields.debug = solver_input.debug
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_interp_scalar_field.py:44, in interpolate_scalar_field(solver_input, options)
#      40     weights = WeightsBuffer.get(solver_input, options.kernel_options)
#      42 # endregion
# ---> 44 exported_fields: ExportedFields = _evaluate_sys_eq(solver_input, weights, options)
#      46 return weights, exported_fields
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_interp_scalar_field.py:77, in _evaluate_sys_eq(solver_input, weights, options)
#      74 def _evaluate_sys_eq(solver_input: SolverInput, weights: np.ndarray, options: InterpolationOptions) -> ExportedFields:
#      75     compute_gradient: bool = options.compute_scalar_gradient
# ---> 77     eval_kernel = kernel_constructor.yield_evaluation_kernel(solver_input, options.kernel_options)
#      79     if BackendTensor.pykeops_enabled is True:
#      80         if solver_input.xyz_to_interpolate.flags['C_CONTIGUOUS'] is False:  # ! This is not working with TF yet
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\modules\kernel_constructor\kernel_constructor_interface.py:25, in yield_evaluation_kernel(interp_input, kernel_options)
#      23 def yield_evaluation_kernel(interp_input: SolverInput, kernel_options: KernelOptions):
#      24     kernel_data = evaluation_vectors_preparations(interp_input, kernel_options)
# ---> 25     return create_scalar_kernel(kernel_data, kernel_options)
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\modules\kernel_constructor\_kernels_assembler.py:44, in create_scalar_kernel(ki, options)
#      41 c_o = options.c_o
#      43 # region distances
# ---> 44 dm = _compute_all_distance_matrices(
#      45     cs=ki.cartesian_selector,
#      46     ori_sp_matrices=ki.ori_sp_matrices,
#      47     square_distance=kernel_f.consume_sq_distance,
#      48     is_gradient=False
#      49 )
#      51 k_a, k_p_ref, k_p_rest, k_ref_ref, k_ref_rest, k_rest_ref, k_rest_rest = _compute_all_kernel_terms(
#      52     range_=a,
#      53     kernel_functions=kernel_f,
#    (...)
#      57     r_rest_rest=dm.r_rest_rest
#      58 )
#      60 # endregion
#      61
#      62 # region sp and grad-sp
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\modules\kernel_constructor\_kernels_assembler.py:165, in _compute_all_distance_matrices(cs, ori_sp_matrices, square_distance, is_gradient, is_testing)
#     160     distance_matrices: InternalDistancesMatrices = _compute_distances_using_cache(
#     161         cs=cs,
#     162         last_internal_distances_matrices=DistancesBuffer.last_internal_distances_matrices
#     163     )
#     164 else:
# --> 165     distance_matrices: InternalDistancesMatrices = _compute_distances_new(
#     166         cs=cs,
#     167         ori_sp_matrices=ori_sp_matrices,
#     168         square_distance=square_distance
#     169     )
#     171 if develeping_distances_buffer := False and is_gradient:  # This is for developing
#     172     _check_which_items_are_the_same_between_calls(distance_matrices)
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\modules\kernel_constructor\_kernels_assembler.py:221, in _compute_distances_new(cs, ori_sp_matrices, square_distance)
#     220 def _compute_distances_new(cs: CartesianSelector, ori_sp_matrices, square_distance) -> InternalDistancesMatrices:
# --> 221     dif_ref_ref = ori_sp_matrices.dip_ref_i - ori_sp_matrices.dip_ref_j  # Can be cached
#     222     dif_rest_rest = ori_sp_matrices.diprest_i - ori_sp_matrices.diprest_j  # Can be cached
#     224     hu = bt.t.sum(dif_ref_ref * (cs.hu_sel_i * cs.hu_sel_j), axis=-1)  # Can be cached
#
# MemoryError: Unable to allocate 1.40 GiB for an array with shape (499, 125480, 3) and data type float64

# %% [markdown]
# # Com Numpy:
# - GPU 12%, GPU 25%, RAM 50%.
# - Tempo de processamento: 4m20s

# %%
"""model = gp.compute_model(
    geo_model,
    engine_config=gp.data.GemPyEngineConfig(
        backend=gp.data.AvailableBackends.PYTORCH, # Padrão é numpy, só comentar essa parte
        use_gpu=True, # para usar o GPU (não sei se funciona sem CUDA - testar)
        dtype="float64", #"float32"
    ))"""
# Out:
# Setting Backend To: AvailableBackends.PYTORCH
# Condition number: 4255989.703141975.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model = gp.compute_model(
#       2     geo_model,
#       3     engine_config=gp.data.GemPyEngineConfig(
#       4         backend=gp.data.AvailableBackends.PYTORCH, # Padrão é numpy, só comentar essa parte
#       5         use_gpu=True, # para usar o GPU (não sei se funciona sem CUDA - testar)
#       6         dtype="float64", #"float32"
#       7     ))
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy\API\compute_API.py:48, in compute_model(gempy_model, engine_config)
#      45     interpolation_input = gempy_model.interpolation_input
#      46     gempy_model.taped_interpolation_input = interpolation_input
# ---> 48     gempy_model.solutions = gempy_engine.compute_model(
#      49         interpolation_input=interpolation_input,
#      50         options=gempy_model.interpolation_options,
#      51         data_descriptor=gempy_model.input_data_descriptor,
#      52         geophysics_input=gempy_model.geophysics_input,
#      53     )
#      55 case AvailableBackends.aesara | AvailableBackends.legacy:
#      56     gempy_model.legacy_model = _legacy_compute_model(gempy_model)
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\model\model_api.py:31, in compute_model(interpolation_input, options, data_descriptor, geophysics_input)
#      28 if BackendTensor.engine_backend is not AvailableBackends.PYTORCH and COMPUTE_GRADIENTS is False:
#      29     interpolation_input = copy.deepcopy(interpolation_input)
# ---> 31 output: list[OctreeLevel] = interpolate_n_octree_levels(
#      32     interpolation_input=interpolation_input,
#      33     options=options,
#      34     data_descriptor=data_descriptor
#      35 )
#      37 # region Geophysics
#      38 # ---------------------
#      39
#      40 # TODO: [ ] Gravity
#      41
#      42 # TODO: [ ] Magnetics
#      44 if geophysics_input is not None:
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\interp_features.py:33, in interpolate_n_octree_levels(interpolation_input, options, data_descriptor)
#      30 options.current_octree_level = i
#      32 # * Here it goes all the different grids
# ---> 33 next_octree: OctreeLevel = interpolate_on_octree(interpolation_input, options, data_descriptor)
#      35 if options.is_last_octree_level is False:
#      36     # * This is only a Grid with a Regular grid
#      37     grid_1_centers: Grid = get_next_octree_grid(
#      38         prev_octree=next_octree,
#      39         compute_topology=False,
#      40         debug=False
#      41     )
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_octree_generation.py:37, in interpolate_on_octree(interpolation_input, options, data_shape)
#      33     grid_0_corners = Grid.from_xyz_coords(
#      34         xyz_coords=_generate_corners(regular_grid=grid_0_centers.regular_grid)
#      35     )
#      36     temp_interpolation_input.grid = grid_0_corners  # * Prepare grid for next interpolation
# ---> 37     output_0_corners: List[InterpOutput] = interpolate_all_fields(temp_interpolation_input, options, data_shape)  # * This is unnecessary for the last level except for Dual contouring
#      38 else:
#      39     output_0_corners = []
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_multi_scalar_field_manager.py:28, in interpolate_all_fields(interpolation_input, options, data_descriptor)
#      24 def interpolate_all_fields(interpolation_input: InterpolationInput, options: InterpolationOptions,
#      25                            data_descriptor: InputDataDescriptor) -> List[InterpOutput]:
#      26     """Interpolate all scalar fields given a xyz array of points"""
# ---> 28     all_scalar_fields_outputs: List[ScalarFieldOutput] = _interpolate_stack(data_descriptor, interpolation_input, options)
#      30     combined_scalar_output: List[CombinedScalarFieldsOutput] = _combine_scalar_fields(
#      31         all_scalar_fields_outputs = all_scalar_fields_outputs,
#      32         lithology_mask            = _lithology_mask(all_scalar_fields_outputs, data_descriptor.stack_relation),
#      33         faults_mask               = _faults_mask(all_scalar_fields_outputs, data_descriptor.stack_relation),
#      34         compute_scalar_grad       = options.compute_scalar_gradient
#      35     )
#      37     all_outputs = []
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_multi_scalar_field_manager.py:84, in _interpolate_stack(root_data_descriptor, root_interpolation_input, options)
#      81         interpolation_input_i.fault_values = fault_input
#      83         solver_input = input_preprocess(tensor_struct_i, interpolation_input_i)
# ---> 84         output: ScalarFieldOutput = interpolate_feature(
#      85             interpolation_input    = interpolation_input_i,
#      86             options                = options,
#      87             data_shape             = tensor_struct_i,
#      88             solver_input           = solver_input,
#      89             external_interp_funct  = stack_structure.interp_function,
#      90             external_segment_funct = stack_structure.segmentation_function
#      91         )
#      93 # @on
#      94         all_scalar_fields_outputs[i] = output
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_interp_single_feature.py:38, in interpolate_feature(interpolation_input, options, data_shape, solver_input, external_interp_funct, external_segment_funct, clean_buffer)
#      35 xyz = solver_input.xyz_to_interpolate
#      37 if external_interp_funct is None:  # * EXTERNAL INTERPOLATION FUNCTION branching
# ---> 38     weights, exported_fields = interpolate_scalar_field(solver_input, options)
#      40     exported_fields.set_structure_values(
#      41         reference_sp_position = data_shape.reference_sp_position,
#      42         slice_feature         = interpolation_input.slice_feature,
#      43         grid_size             = interpolation_input.grid.len_all_grids
#      44     )
#      46     exported_fields.debug = solver_input.debug
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_interp_scalar_field.py:44, in interpolate_scalar_field(solver_input, options)
#      40     weights = WeightsBuffer.get(solver_input, options.kernel_options)
#      42 # endregion
# ---> 44 exported_fields: ExportedFields = _evaluate_sys_eq(solver_input, weights, options)
#      46 return weights, exported_fields
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\API\interp_single\_interp_scalar_field.py:77, in _evaluate_sys_eq(solver_input, weights, options)
#      74 def _evaluate_sys_eq(solver_input: SolverInput, weights: np.ndarray, options: InterpolationOptions) -> ExportedFields:
#      75     compute_gradient: bool = options.compute_scalar_gradient
# ---> 77     eval_kernel = kernel_constructor.yield_evaluation_kernel(solver_input, options.kernel_options)
#      79     if BackendTensor.pykeops_enabled is True:
#      80         if solver_input.xyz_to_interpolate.flags['C_CONTIGUOUS'] is False:  # ! This is not working with TF yet
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\modules\kernel_constructor\kernel_constructor_interface.py:25, in yield_evaluation_kernel(interp_input, kernel_options)
#      23 def yield_evaluation_kernel(interp_input: SolverInput, kernel_options: KernelOptions):
#      24     kernel_data = evaluation_vectors_preparations(interp_input, kernel_options)
# ---> 25     return create_scalar_kernel(kernel_data, kernel_options)
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\modules\kernel_constructor\_kernels_assembler.py:69, in create_scalar_kernel(ki, options)
#      65 # endregion
#      66
#      67 # region universal_sp
#      68 usp_ref = bt.t.sum(ki.ref_drift.dipsPoints_ui_ai * ki.ref_drift.dipsPoints_ui_aj, axis=-1)
# ---> 69 usp_ref_d2b = bt.t.sum(ki.ref_drift.dipsPoints_ui_bi1 * ki.ref_drift.dipsPoints_ui_bj1, axis=-1)
#      70 usp_ref_d2c = bt.t.sum(ki.ref_drift.dipsPoints_ui_bi2 * ki.ref_drift.dipsPoints_ui_bj2, axis=-1)
#      72 usp_ref_d2 = usp_ref_d2b * usp_ref_d2c
#
# File c:\Users\BernardoPR4\anaconda3\envs\gempy_3\lib\site-packages\gempy_engine\core\backend_tensor.py:162, in BackendTensor._wrap_pytorch_functions.<locals>._sum(tensor, axis, dtype, keepdim)
#     159 if isinstance(dtype, str):
#     160     dtype = getattr(torch, dtype)
# --> 162 return sum(tensor, axis, dtype=dtype, keepdim=keepdim)
#
# RuntimeError: [enforce fail at alloc_cpu.cpp:80] data. DefaultCPUAllocator: not enough memory: you tried to allocate 3993916160 bytes.

# %%
"""model = gp.compute_model(
    geo_model,
    engine_config=gp.data.GemPyEngineConfig(
        backend=gp.data.AvailableBackends.PYTORCH, # Padrão é numpy, só comentar essa parte
        use_gpu=True, # para usar o GPU (não sei se funciona sem CUDA - testar)
        #dtype="float64", "float32"
    ))"""
# Out:
# 'model = gp.compute_model(\n    geo_model,\n    engine_config=gp.data.GemPyEngineConfig(\n        backend=gp.data.AvailableBackends.PYTORCH, # Padrão é numpy, só comentar essa parte\n        use_gpu=True, # para usar o GPU (não sei se funciona sem CUDA - testar)\n        #dtype="float64", "float32"\n    ))'

# %%
gpv.plot_2d(geo_model, direction="y", show_data=True, show_lith=True, ve=5, legend=True)
gpv.plot_2d(geo_model, direction="x", show_data=True, show_lith=True, ve=5, legend=True)

# %%
gempy_vista_model = gpv.plot_3d(
    geo_model,
    plotter_type="basic",  # Use 'notebook' instead of 'basic'
    ve=5,
    show_values=False,
    show_block=True,
    show=False  # This prevents the plot from being shown immediately
)

# 
plotter = gempy_vista_model.p

# Adiciona uma luz
#plotter.enable_eye_dome_lighting()

# Customize the plot
#plotter.show_grid(all_edges=False)
plotter.show_bounds(font_size=6, location="furthest") # show_xaxis=False, show_yaxis=False, show_zaxis=Falsehttps://docs.pyvista.org/version/stable/api/plotting/_autosummary/pyvista.renderer.show_bounds#pyvista.Renderer.show_bounds
#plotter.add_text("BES", position=(500, 700, 1000), font_size=20)
plotter.set_background("white")
#plotter.border_color = "black" 

# Show the plot
plotter.show()

# %%
gempy_vista_model

# %%
"""import pickle
with open('geo_model.pkl', 'wb') as f:
    pickle.dump(geo_model, f)"""

# %%
#gpv.plot_2d(geo_model, show_topography=False, section_names=['meio'], show_lith=True)

# %%
"""gpv.plot_2d(geo_model, cell_number=[4], direction=['y'], show_topography=True, show_data=True)
gpv.plot_2d(geo_model, cell_number=[-4], direction=['y'], show_topography=True, show_data=True)"""

# %%
#gpv.plot_3d(geo_model, show_lith=True, show_topography=False, kwargs_plot_structured_grid={'opacity': 0.8})
