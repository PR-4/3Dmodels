# %%
# Dependencies
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gempy.assets import topology as tp

import warnings

warnings.filterwarnings("ignore")

pd.set_option("precision", 2)

# Creating model object and indicating path
data_path = "../../../input/BES/dionisos_horizons_v2/gempy_format/"
geo_model = gp.create_model("Dionisos_Horizons_BES_v2")
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Step by step

# %%
# Loading model, the extension, the resolution and importing the data
gp.init_data(
    geo_model,
    extent=[0, 175000, 0, 145000, -24000, 0],
    resolution=[50, 50, 50],
    path_i=data_path + "merged_sp_z_ajusted.csv",
    # path_o=data_path + "orientations_points.csv",
)
# Out:
# Active grids: ['regular']
# Dionisos_Horizons_BES_v2  2023-09-25 12:11

# %%
gp.get_data(
    geo_model,
    "surfaces",
)
# Out:
#        surface          series  order_surfaces    color  id
# 0    Horizon_1  Default series               1  #015482   1
# 1    Horizon_2  Default series               2  #9f0052   2
# 2    Horizon_3  Default series               3  #ffbe00   3
# 3    Horizon_4  Default series               4  #728f02   4
# 4    Horizon_5  Default series               5  #443988   5
# 5    Horizon_6  Default series               6  #ff3f20   6
# 6    Horizon_7  Default series               7  #5DA629   7
# 7    Horizon_8  Default series               8  #4878d0   8
# 8    Horizon_9  Default series               9  #ee854a   9
# 9   Horizon_10  Default series              10  #6acc64  10
# 10  Horizon_11  Default series              11  #d65f5f  11
# 11  Horizon_12  Default series              12  #956cb4  12
# 12  Horizon_13  Default series              13  #8c613c  13
# 13  Horizon_14  Default series              14  #dc7ec0  14
# 14  Horizon_15  Default series              15  #797979  15
# 15  Horizon_16  Default series              16  #d5bb67  16
# 16  Horizon_17  Default series              17  #82c6e2  17
# 17  Horizon_18  Default series              18  #a1c9f4  18
# 18  Horizon_19  Default series              19  #ffb482  19
# 19  Horizon_20  Default series              20  #8de5a1  20
# 20  Horizon_21  Default series              21  #ff9f9b  21
# 21  Horizon_22  Default series              22  #d0bbff  22
# 22  Horizon_23  Default series              23  #debb9b  23
# 23  Horizon_24  Default series              24  #fab0e4  24
# 24  Horizon_25  Default series              25  #cfcfcf  25
# 25  Horizon_26  Default series              26  #fffea3  26
# 26  Horizon_27  Default series              27  #b9f2f0  27
# 27    basement        Basement               1  #4c72b0  28

# %%
# Ordenando as surfaces (Estratigrafia (topo para base)) 1
gp.map_stack_to_surfaces(
    geo_model,
    {
        "Strat_Series": (
            "Horizon_1",
            "Horizon_2",
            "Horizon_3",
            "Horizon_4",
            "Horizon_5",
            "Horizon_6",
            "Horizon_7",
            "Horizon_8",
            "Horizon_9",
            "Horizon_10",
            "Horizon_11",
            "Horizon_12",
            "Horizon_13",
            "Horizon_14",
            "Horizon_15",
            "Horizon_16",
            "Horizon_17",
            "Horizon_18",
            "Horizon_19",
            "Horizon_20",
            "Horizon_21",
            "Horizon_22",
            "Horizon_23",
            "Horizon_24",
            "Horizon_25",
            "Horizon_26",
            "Horizon_27",
        ),
        "Basement_series": ("basement",),
    },
)
# Out:
#        surface           series  order_surfaces    color  id
# 0    Horizon_1     Strat_Series               1  #015482   1
# 1    Horizon_2     Strat_Series               2  #9f0052   2
# 2    Horizon_3     Strat_Series               3  #ffbe00   3
# 3    Horizon_4     Strat_Series               4  #728f02   4
# 4    Horizon_5     Strat_Series               5  #443988   5
# 5    Horizon_6     Strat_Series               6  #ff3f20   6
# 6    Horizon_7     Strat_Series               7  #5DA629   7
# 7    Horizon_8     Strat_Series               8  #4878d0   8
# 8    Horizon_9     Strat_Series               9  #ee854a   9
# 9   Horizon_10     Strat_Series              10  #6acc64  10
# 10  Horizon_11     Strat_Series              11  #d65f5f  11
# 11  Horizon_12     Strat_Series              12  #956cb4  12
# 12  Horizon_13     Strat_Series              13  #8c613c  13
# 13  Horizon_14     Strat_Series              14  #dc7ec0  14
# 14  Horizon_15     Strat_Series              15  #797979  15
# 15  Horizon_16     Strat_Series              16  #d5bb67  16
# 16  Horizon_17     Strat_Series              17  #82c6e2  17
# 17  Horizon_18     Strat_Series              18  #a1c9f4  18
# 18  Horizon_19     Strat_Series              19  #ffb482  19
# 19  Horizon_20     Strat_Series              20  #8de5a1  20
# 20  Horizon_21     Strat_Series              21  #ff9f9b  21
# 21  Horizon_22     Strat_Series              22  #d0bbff  22
# 22  Horizon_23     Strat_Series              23  #debb9b  23
# 23  Horizon_24     Strat_Series              24  #fab0e4  24
# 24  Horizon_25     Strat_Series              25  #cfcfcf  25
# 25  Horizon_26     Strat_Series              26  #fffea3  26
# 26  Horizon_27     Strat_Series              27  #b9f2f0  27
# 27    basement  Basement_series               1  #4c72b0  28

# %%
geo_model.set_default_orientation()

# %%
# Seção transversal do modelo
gp.plot_2d(geo_model, direction="y", show_data=True, show_lith=True, ve=2, legend=False)
gp.plot_2d(geo_model, direction="x", show_data=True, show_lith=True, ve=2, legend=False)
# gp.plot_2d(geo_model, direction="z", show_data=True, show_lith=True, ve=1, legend=False)

# %%
# geo_model.set_default_orientation()

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(
    geo_model,
    plotter_type="basic",
    image=False,
    show_data=True,
    show_surfaces=True,
    show_scalar=True,
    show_boundaries=True,
    ve=1,
)

# %%
# %%time
gp.set_interpolator(
    geo_model, 
    output=['geology'], 
    compile_theano=True, 
    theano_optimizer='fast_run', # fast_compile, fast_run
    dtype="float64",  # for model stability
    verbose=[]
)
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_run
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                          values
# range                228530.09
# $C_o$            1243476190.48
# drift equations         [3, 3]
# Wall time: 25 s

# %%
# %%time
gp.compute_model(
    geo_model, 
    compute_mesh=True,
    )

# %%
# Seção transversal do modelo
gp.plot_2d(
    geo_model,
    direction="y",
    show_data=False,
    show_lith=True,
    ve=1,
)
gp.plot_2d(
    geo_model,
    direction="x",
    show_data=False,
    show_lith=True,
    ve=2,
    legend=True,
)

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(geo_model, image=False, plotter_type="basic", show_data=False, ve=10)

# %%
"""topo_init = tp.compute_topology(
    geo_model, direction="x", voxel_threshold=1
)  # , direction="Y", cell_number=15)
edges_init, centroids_init = tp.clean_unconformity_topology(
    geo_model, 1, topo_init[0], topo_init[1]
)"""

# %%
"""# Seção transversal do modelo
gp.plot_2d(
    geo_model,
    direction="y",
    show_data=False,
    show_lith=True,
    ve=1,
)
gp.plot_2d(
    geo_model,
    direction="x",
    show_data=False,
    show_lith=True,
    ve=2,
    legend=True,
)"""

# %%
"""# Seção transversal do modelo
gp.plot_2d(
    geo_model,
    direction="y",
    show_data=False,
    show_lith=True,
    ve=1,
)
gp.plot.plot_topology(geo_model, edges_init, centroids_init)"""

# %%
"""# Salvar o modelo gerado em zip (contem todos os files relevantes para refazer o modelo)
gp.save_model(
    geo_model,
    path="../../../output/",
    compress=True,
)"""
