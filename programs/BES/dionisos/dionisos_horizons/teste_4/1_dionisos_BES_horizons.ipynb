# %%
# Dependencies
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from gempy.assets import topology as tp

import warnings

warnings.filterwarnings("ignore")

pd.set_option("display.precision", 2)

# Creating model object and indicating path
data_path = "../../../../../input/BES/dionisos/dionisos_horizons/gempy_format/teste_4/"
nome_modelo = "Dionisos_Horizons_BES_teste4"
geo_model = gp.create_model(nome_modelo)
# Out:
# No module named 'osgeo'

# %% [markdown]
# ### Detalhes dos dados
# - Contém todos os horizontes gerados do dionisos e convertido para .csv
# - Todos os horizontes foram reduzidos em X e Y para diminuir a quantidade de pontos (1000)
# - Todos os Z dos hoziontes 2 até o último foram adicionados com -mil metros a mais para aumentar a distância entre eles
# - Cada horizonte (surface no GemPy) é uma série
# - Ponto de orientação gerado com KNN pelo GemPy (Quando salvar a orientação gerada, precisa trocar o header surfaces para formation, se for abrir o .csv ao invés de rodar sempre o KNN)

# %% [markdown]
# ## Step by step

# %%
# Loading model, the extension, the resolution and importing the data
gp.init_data(
    geo_model,
    extent=[0, 175000, 0, 145000, -24000, 0],
    resolution=[20, 20, 20],
    path_i=data_path + "merged_horizons_sp_full.csv",
    #path_o=data_path + "orientations_points_2.csv",
)
# Out:
# Active grids: ['regular']
# Dionisos_Horizons_BES_teste4  2024-03-25 18:11

# %%
gp.get_data(
    geo_model,
    "surfaces",
)
# Out:
#        surface          series  order_surfaces    color  id
# 0    Horizon_1  Default series               1  #015482   1
# 1    Horizon_2  Default series               2  #9f0052   2
# 2    Horizon_3  Default series               3  #ffbe00   3
# 3    Horizon_4  Default series               4  #728f02   4
# 4    Horizon_5  Default series               5  #443988   5
# 5    Horizon_6  Default series               6  #ff3f20   6
# 6    Horizon_7  Default series               7  #5DA629   7
# 7    Horizon_8  Default series               8  #4878d0   8
# 8    Horizon_9  Default series               9  #ee854a   9
# 9   Horizon_10  Default series              10  #6acc64  10
# 10  Horizon_11  Default series              11  #d65f5f  11
# 11  Horizon_12  Default series              12  #956cb4  12
# 12  Horizon_13  Default series              13  #8c613c  13
# 13  Horizon_14  Default series              14  #dc7ec0  14
# 14  Horizon_15  Default series              15  #797979  15
# 15  Horizon_16  Default series              16  #d5bb67  16
# 16  Horizon_17  Default series              17  #82c6e2  17
# 17  Horizon_18  Default series              18  #a1c9f4  18
# 18  Horizon_19  Default series              19  #ffb482  19
# 19  Horizon_20  Default series              20  #8de5a1  20
# 20  Horizon_21  Default series              21  #ff9f9b  21
# 21  Horizon_22  Default series              22  #d0bbff  22
# 22  Horizon_23  Default series              23  #debb9b  23
# 23  Horizon_24  Default series              24  #fab0e4  24
# 24  Horizon_25  Default series              25  #cfcfcf  25
# 25  Horizon_26  Default series              26  #fffea3  26
# 26  Horizon_27  Default series              27  #b9f2f0  27
# 27    basement        Basement               1  #4c72b0  28

# %%
# Ordenando as surfaces (Estratigrafia (topo para base)) 1
gp.map_stack_to_surfaces(
    geo_model,
    {
        "Strat_1": (
            "Horizon_1",),
        "Strat_2": (
            "Horizon_2",),
        "Strat_3": (
            "Horizon_3",),
        "Strat_4": (
            "Horizon_4",),
        "Strat_5": (
            "Horizon_5",),
        "Strat_6": (
            "Horizon_6",),
        "Strat_7": (
            "Horizon_7",),
        "Strat_8": (
            "Horizon_8",),
        "Strat_9": (
            "Horizon_9",),
        "Strat_10": (
            "Horizon_10",),
        "Strat_11": (
            "Horizon_11",),
        "Strat_12": (
            "Horizon_12",),
        "Strat_13": (
            "Horizon_13",),
        "Strat_14": (
            "Horizon_14",),
        "Strat_15": (
            "Horizon_15",),
        "Strat_16": (
            "Horizon_16",),
        "Strat_17": (
            "Horizon_17",),
        "Strat_18": (
            "Horizon_18",),
        "Strat_19": (
            "Horizon_19",),
        "Strat_20": (
            "Horizon_20",),
        "Strat_21": (
            "Horizon_21",),
        "Strat_22": (
            "Horizon_22",),
        "Strat_23": (
            "Horizon_23",),
        "Strat_24": (
            "Horizon_24",),
        "Strat_25": (
            "Horizon_25",),
        "Strat_26": (
            "Horizon_26",),
        "Strat_27": (
            "Horizon_27",),
        "Basement_series": ("basement",),
    }
)
# Out:
#        surface           series  order_surfaces    color  id
# 0    Horizon_1          Strat_1               1  #015482   1
# 1    Horizon_2          Strat_2               1  #9f0052   2
# 2    Horizon_3          Strat_3               1  #ffbe00   3
# 3    Horizon_4          Strat_4               1  #728f02   4
# 4    Horizon_5          Strat_5               1  #443988   5
# 5    Horizon_6          Strat_6               1  #ff3f20   6
# 6    Horizon_7          Strat_7               1  #5DA629   7
# 7    Horizon_8          Strat_8               1  #4878d0   8
# 8    Horizon_9          Strat_9               1  #ee854a   9
# 9   Horizon_10         Strat_10               1  #6acc64  10
# 10  Horizon_11         Strat_11               1  #d65f5f  11
# 11  Horizon_12         Strat_12               1  #956cb4  12
# 12  Horizon_13         Strat_13               1  #8c613c  13
# 13  Horizon_14         Strat_14               1  #dc7ec0  14
# 14  Horizon_15         Strat_15               1  #797979  15
# 15  Horizon_16         Strat_16               1  #d5bb67  16
# 16  Horizon_17         Strat_17               1  #82c6e2  17
# 17  Horizon_18         Strat_18               1  #a1c9f4  18
# 18  Horizon_19         Strat_19               1  #ffb482  19
# 19  Horizon_20         Strat_20               1  #8de5a1  20
# 20  Horizon_21         Strat_21               1  #ff9f9b  21
# 21  Horizon_22         Strat_22               1  #d0bbff  22
# 22  Horizon_23         Strat_23               1  #debb9b  23
# 23  Horizon_24         Strat_24               1  #fab0e4  24
# 24  Horizon_25         Strat_25               1  #cfcfcf  25
# 25  Horizon_26         Strat_26               1  #fffea3  26
# 26  Horizon_27         Strat_27               1  #b9f2f0  27
# 27    basement  Basement_series               1  #4c72b0  28

# %%
geo_model.get_data()
# Out:
#                              X         Y       Z    smooth     surface  G_x
# surface_points 0           0.0       0.0 -1503.0  2.00e-06   Horizon_1  NaN  \
#                1        5000.0       0.0 -1574.0  2.00e-06   Horizon_1  NaN
#                2       10000.0       0.0 -1645.0  2.00e-06   Horizon_1  NaN
#                3       15000.0       0.0 -1720.0  2.00e-06   Horizon_1  NaN
#                4       20000.0       0.0 -1786.0  2.00e-06   Horizon_1  NaN
# ...                        ...       ...     ...       ...         ...  ...
#                30127  155000.0  150000.0 -9019.0  2.00e-06  Horizon_27  NaN
#                30128  160000.0  150000.0 -9021.0  2.00e-06  Horizon_27  NaN
#                30129  165000.0  150000.0 -8849.0  2.00e-06  Horizon_27  NaN
#                30130  170000.0  150000.0 -8979.0  2.00e-06  Horizon_27  NaN
#                30131  175000.0  150000.0 -9002.0  2.00e-06  Horizon_27  NaN
#
#                       G_y  G_z
# surface_points 0      NaN  NaN
#                1      NaN  NaN
#                2      NaN  NaN
#                3      NaN  NaN
#                4      NaN  NaN
# ...                   ...  ...
#                30127  NaN  NaN
#                30128  NaN  NaN
#                30129  NaN  NaN
#                30130  NaN  NaN
#                30131  NaN  NaN
#
# [30132 rows x 8 columns]

# %%
neighbours = gp.select_nearest_surfaces_points(geo_model, geo_model.surface_points.df, 10)
opoints = gp.set_orientation_from_neighbours_all(geo_model, neighbours)

# %%
orientations_p = geo_model.orientations.df
orientations_p.to_csv(data_path + "orientations_points.csv")
orientations_p
# Out:
#               X         Y       Z   X_c   Y_c   Z_c       G_x       G_y  G_z
# 0           0.0       0.0 -1503.0  0.25  0.29  0.51  1.29e-02  1.42e-03  1.0  \
# 1        5000.0       0.0 -1574.0  0.26  0.29  0.51  1.28e-02  2.83e-04  1.0
# 2       10000.0       0.0 -1645.0  0.28  0.29  0.51  1.35e-02 -9.00e-04  1.0
# 3       15000.0       0.0 -1720.0  0.29  0.29  0.51  1.37e-02 -2.37e-03  1.0
# 4       20000.0       0.0 -1786.0  0.31  0.29  0.51  1.40e-02 -3.20e-03  1.0
# ...         ...       ...     ...   ...   ...   ...       ...       ...  ...
# 22315  155000.0  150000.0 -9019.0  0.69  0.71  0.49  6.39e-03 -1.98e-02  1.0
# 22316  160000.0  150000.0 -9021.0  0.71  0.71  0.49 -7.40e-04 -2.86e-02  1.0
# 22317  165000.0  150000.0 -8849.0  0.72  0.71  0.49  6.41e-04 -3.76e-02  1.0
# 22318  170000.0  150000.0 -8979.0  0.74  0.71  0.49  5.73e-03 -4.04e-02  1.0
# 22319  175000.0  150000.0 -9002.0  0.75  0.71  0.49  8.13e-03 -3.33e-02  1.0
#
#         dip  azimuth  polarity     surface    series    id  order_series
# 0      0.74    83.68       1.0   Horizon_1   Strat_1   1.0           1.0  \
# 1      0.73    88.73       1.0   Horizon_1   Strat_1   1.0           1.0
# 2      0.78    93.81       1.0   Horizon_1   Strat_1   1.0           1.0
# 3      0.80    99.80       1.0   Horizon_1   Strat_1   1.0           1.0
# 4      0.83   102.84       1.0   Horizon_1   Strat_1   1.0           1.0
# ...     ...      ...       ...         ...       ...   ...           ...
# 22315  1.19   162.10       1.0  Horizon_27  Strat_27  27.0          27.0
# 22316  1.64   181.48       1.0  Horizon_27  Strat_27  27.0          27.0
# 22317  2.16   179.02       1.0  Horizon_27  Strat_27  27.0          27.0
# 22318  2.34   171.94       1.0  Horizon_27  Strat_27  27.0          27.0
# 22319  1.96   166.27       1.0  Horizon_27  Strat_27  27.0          27.0
#
#        smooth
# 0        0.01
# 1        0.01
# 2        0.01
# 3        0.01
# 4        0.01
# ...       ...
# 22315    0.01
# 22316    0.01
# 22317    0.01
# 22318    0.01
# 22319    0.01
#
# [30132 rows x 17 columns]

# %%
# Trocando o nome de surface para formation (necessário se for importar no Gempy)
orientations_p_formation = orientations_p.copy()
orientations_p_formation = orientations_p_formation.rename(columns={'surface': 'formation'})
orientations_p_formation.to_csv(data_path + "orientations_points_2.csv")
orientations_p_formation
# Out:
#               X         Y       Z   X_c   Y_c   Z_c       G_x       G_y  G_z
# 0           0.0       0.0 -1503.0  0.25  0.29  0.51  1.29e-02  1.42e-03  1.0  \
# 1        5000.0       0.0 -1574.0  0.26  0.29  0.51  1.28e-02  2.83e-04  1.0
# 2       10000.0       0.0 -1645.0  0.28  0.29  0.51  1.35e-02 -9.00e-04  1.0
# 3       15000.0       0.0 -1720.0  0.29  0.29  0.51  1.37e-02 -2.37e-03  1.0
# 4       20000.0       0.0 -1786.0  0.31  0.29  0.51  1.40e-02 -3.20e-03  1.0
# ...         ...       ...     ...   ...   ...   ...       ...       ...  ...
# 22315  155000.0  150000.0 -9019.0  0.69  0.71  0.49  6.39e-03 -1.98e-02  1.0
# 22316  160000.0  150000.0 -9021.0  0.71  0.71  0.49 -7.40e-04 -2.86e-02  1.0
# 22317  165000.0  150000.0 -8849.0  0.72  0.71  0.49  6.41e-04 -3.76e-02  1.0
# 22318  170000.0  150000.0 -8979.0  0.74  0.71  0.49  5.73e-03 -4.04e-02  1.0
# 22319  175000.0  150000.0 -9002.0  0.75  0.71  0.49  8.13e-03 -3.33e-02  1.0
#
#         dip  azimuth  polarity   formation    series    id  order_series
# 0      0.74    83.68       1.0   Horizon_1   Strat_1   1.0           1.0  \
# 1      0.73    88.73       1.0   Horizon_1   Strat_1   1.0           1.0
# 2      0.78    93.81       1.0   Horizon_1   Strat_1   1.0           1.0
# 3      0.80    99.80       1.0   Horizon_1   Strat_1   1.0           1.0
# 4      0.83   102.84       1.0   Horizon_1   Strat_1   1.0           1.0
# ...     ...      ...       ...         ...       ...   ...           ...
# 22315  1.19   162.10       1.0  Horizon_27  Strat_27  27.0          27.0
# 22316  1.64   181.48       1.0  Horizon_27  Strat_27  27.0          27.0
# 22317  2.16   179.02       1.0  Horizon_27  Strat_27  27.0          27.0
# 22318  2.34   171.94       1.0  Horizon_27  Strat_27  27.0          27.0
# 22319  1.96   166.27       1.0  Horizon_27  Strat_27  27.0          27.0
#
#        smooth
# 0        0.01
# 1        0.01
# 2        0.01
# 3        0.01
# 4        0.01
# ...       ...
# 22315    0.01
# 22316    0.01
# 22317    0.01
# 22318    0.01
# 22319    0.01
#
# [30132 rows x 17 columns]

# %%
geo_model.get_data()
# Out:
#                              X         Y       Z    smooth     surface
# surface_points 0           0.0       0.0 -1503.0  2.00e-06   Horizon_1  \
#                1        5000.0       0.0 -1574.0  2.00e-06   Horizon_1
#                2       10000.0       0.0 -1645.0  2.00e-06   Horizon_1
#                3       15000.0       0.0 -1720.0  2.00e-06   Horizon_1
#                4       20000.0       0.0 -1786.0  2.00e-06   Horizon_1
# ...                        ...       ...     ...       ...         ...
# orientations   22315  155000.0  150000.0 -9019.0  1.00e-02  Horizon_27
#                22316  160000.0  150000.0 -9021.0  1.00e-02  Horizon_27
#                22317  165000.0  150000.0 -8849.0  1.00e-02  Horizon_27
#                22318  170000.0  150000.0 -8979.0  1.00e-02  Horizon_27
#                22319  175000.0  150000.0 -9002.0  1.00e-02  Horizon_27
#
#                            G_x   G_y  G_z
# surface_points 0           NaN   NaN  NaN
#                1           NaN   NaN  NaN
#                2           NaN   NaN  NaN
#                3           NaN   NaN  NaN
#                4           NaN   NaN  NaN
# ...                        ...   ...  ...
# orientations   22315  6.39e-03 -0.02  1.0
#                22316 -7.40e-04 -0.03  1.0
#                22317  6.41e-04 -0.04  1.0
#                22318  5.73e-03 -0.04  1.0
#                22319  8.13e-03 -0.03  1.0
#
# [60264 rows x 8 columns]

# %%
# Seção transversal do modelo
gp.plot_2d(geo_model, direction="y", show_data=True, show_lith=True, ve=5, legend=False)
gp.plot_2d(geo_model, direction="x", show_data=True, show_lith=True, ve=5, legend=False)
# gp.plot_2d(geo_model, direction="z", show_data=True, show_lith=True, ve=5, legend=False)

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(
    geo_model,
    plotter_type="background",
    image=False,
    show_data=True,
    show_surfaces=True,
    show_scalar=True,
    show_boundaries=True,
    ve=5,
)

# %%
# %%time
gp.set_interpolator(
    geo_model, 
    output=['geology'], 
    compile_theano=True, 
    theano_optimizer='fast_run', # fast_compile, fast_run
    dtype="float64",  # for model stability
    verbose=[]
)
# Out:
# Setting kriging parameters to their default values.
# Compiling aesara function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                                                                                                 values
# range                                                                                       228530.09
# $C_o$                                                                                   1243476190.48
# drift equations  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# CPU times: total: 18.2 s
# Wall time: 18.9 s

# %%
geo_model.update_to_interpolator()
# Out:
# True

# %%
# %%time
gp.compute_model(
    geo_model, 
    compute_mesh=True,
    )
# Out:
# CPU times: total: 1h 31min 17s
# Wall time: 18min 1s
# Lithology ids
#   [28. 28. 28. ...  2.  2.  2.]

# %%
# Seção transversal do modelo
gp.plot_2d(
    geo_model,
    direction="y",
    show_data=False,
    show_lith=True,
    ve=1,
)
gp.plot_2d(
    geo_model,
    direction="x",
    show_data=False,
    show_lith=True,
    ve=2,
    legend=True,
)

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(geo_model, image=False, plotter_type="background", show_data=False, ve=5)

# %%
topo_init = tp.compute_topology(
    geo_model, direction="x", voxel_threshold=1
)  # , direction="Y", cell_number=15)
edges_init, centroids_init = tp.clean_unconformity_topology(
    geo_model, 1, topo_init[0], topo_init[1]
)

# %%
# Seção transversal do modelo
gp.plot_2d(
    geo_model,
    direction="y",
    show_data=False,
    show_lith=True,
    ve=1,
)
gp.plot.plot_topology(geo_model, edges_init, centroids_init)

# %%
"""# Salvar o modelo gerado em zip (contem todos os files relevantes para refazer o modelo)
gp.save_model(
    ,
    path="../../../output/",
    compress=True,
)"""

# %%
# Salvar o modelo gerado em zip (contem todos os files relevantes para refazer o modelo)
gp.save_model(
    geo_model,
    compress=True,
)
# Out:
# True

# %%
import pickle
path_save_model = "../../../../../output/BES/Dionisos/dionisos_horizons/teste_4/"
with open(path_save_model + nome_modelo, "wb") as f:
    pickle.dump(geo_model, f)
