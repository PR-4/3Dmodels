# %%
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
data_path = '../input/Teste3/'
geo_model = gp.create_model('SyntheitcBasinTeste3')

# %%
gp.init_data(geo_model, [415000, 470000, 7650000, 8000000, 0, 10000], [50, 50, 50],
            path_i=data_path + "Testando_GEMPY_3_surfaces_points.csv",
            path_0=data_path + "orientations_points.csv")
# Out:
# Active grids: ['regular']
# SyntheitcBasinTeste3  2023-03-10 11:45

# %%
geo_model.surfaces
# Out:
#     surface          series  order_surfaces    color  id
# 0       top  Default series               1  #015482   1
# 1       bot  Default series               2  #9f0052   2
# 2  basement        Basement               1  #ffbe00   3

# %%
gp.get_data(geo_model, 'surface_points').head()
# Out:
#         X        Y    Z    smooth surface
# 0  444546  7967929  390  0.000002     top
# 1  446406  7978062  430  0.000002     top
# 2  459507  7994012   97  0.000002     top
# 3  426016  7927352  403  0.000002     top
# 4  436441  7831586  120  0.000002     top

# %%
geo_model.surfaces
# Out:
#     surface          series  order_surfaces    color  id
# 0       top  Default series               1  #015482   1
# 1       bot  Default series               2  #9f0052   2
# 2  basement        Basement               1  #ffbe00   3

# %%
gp.map_stack_to_surfaces(geo_model, {"Strat_Series": ('top', 'bot')})
# Out:
#     surface        series  order_surfaces    color  id
# 0       top  Strat_Series               1  #015482   1
# 1       bot  Strat_Series               2  #9f0052   2
# 2  basement      Basement               1  #ffbe00   3

# %%
geo_model.stack
# Out:
#               order_series BottomRelation  isActive  isFault  isFinite
# Strat_Series             1        Erosion     False    False     False
# Basement                 2        Erosion     False    False     False

# %%
geo_model.grid
# Out:
# Grid Object. Values:
# array([[4.1555e+05, 7.6535e+06, 1.0000e+02],
#        [4.1555e+05, 7.6535e+06, 3.0000e+02],
#        [4.1555e+05, 7.6535e+06, 5.0000e+02],
#        ...,
#        [4.6945e+05, 7.9965e+06, 9.5000e+03],
#        [4.6945e+05, 7.9965e+06, 9.7000e+03],
#        [4.6945e+05, 7.9965e+06, 9.9000e+03]])

# %%
plot = gp.plot_2d(geo_model, show_lith=False, show_boundaries=False)
plt.show()
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic')
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\pyvista\utilities\helpers.py:508: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   'Points is not a float type. This can cause issues when '

# %%
gp.set_interpolator(geo_model,
                    compile_theano=True,
                    theano_optimizer='fast_compile',
                    )
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                              values
# range                354436.171969
# $C_o$            2991071428.571429
# drift equations             [3, 3]

# %%
sol = gp.compute_model(geo_model)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\anaconda3\envs\gempy\lib\site-packages\theano\compile\function_module.py in __call__(self, *args, **kwargs)
#     902             outputs =\
# --> 903                 self.fn() if output_subset is None else\
#     904                 self.fn(output_subset=output_subset)
#
# ~\anaconda3\envs\gempy\lib\site-packages\theano\scan_module\scan_op.py in rval(p, i, o, n, allow_gc)
#     962                  allow_gc=allow_gc):
# --> 963             r = p(n, [x[0] for x in i], o)
#     964             for o in node.outputs:
#
# ~\anaconda3\envs\gempy\lib\site-packages\theano\scan_module\scan_op.py in p(node, args, outs)
#     951                                                 outs,
# --> 952                                                 self, node)
#     953         except (ImportError, theano.gof.cmodule.MissingGXX):
#
# ...
