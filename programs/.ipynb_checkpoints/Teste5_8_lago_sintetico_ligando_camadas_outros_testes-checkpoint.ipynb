# %%
# Importar dependências
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

import warnings
warnings.filterwarnings("ignore")

pd.set_option('precision', 2)
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# Criando o objeto modelo e variável para indicar a pasta com os dados
data_path = '../input/Teste5/'
geo_model = gp.create_model('SyntheticBasinTeste5')

# %%
# Inicializando os dados, a extensão e a resolução do modelo.
gp.init_data(geo_model,
             extent=[0, 2000, -2000, 2000, -100, 1200],
             resolution=[10, 10, 10],
             path_i=data_path + "8_lago_sintetico_ligando_camadas_outros_testes/surfaces_points.csv")
             #path_o=data_path + "orientations.csv") - caso tenha orientação
# Out:
# Active grids: ['regular']
# SyntheticBasinTeste5  2023-03-17 11:48

# %%
# Ver a ordem das formações
geo_model.surfaces
# Out:
#       surface          series  order_surfaces    color  id
# 0  Formacao_1  Default series               1  #015482   1
# 1  Formacao_2  Default series               2  #9f0052   2
# 2  Formacao_3  Default series               3  #ffbe00   3
# 3  Formacao_4  Default series               4  #728f02   4
# 4    basement        Basement               1  #443988   5

# %%
# Ordenando as surfaces (Estratigrafia (topo para base))
gp.map_stack_to_surfaces(geo_model,                         
                         {"Strat_Series_1": ('Formacao_1', 'Formacao_2'),
                          "Strat_Series_2": ('Formacao_3', 'Formacao_4')})
# Out:
#       surface          series  order_surfaces    color  id
# 0  Formacao_1  Strat_Series_1               1  #015482   1
# 1  Formacao_2  Strat_Series_1               2  #9f0052   2
# 2  Formacao_3  Strat_Series_2               1  #ffbe00   3
# 3  Formacao_4  Strat_Series_2               2  #728f02   4
# 4    basement        Basement               1  #443988   5

# %%
#Criando dados de orientação (Caso não tenha um csv importando)
geo_model.add_orientations(X=1000, Y=500, Z=550, surface="Formacao_2", pole_vector=(0,0,1))
geo_model.add_orientations(X=1000, Y=500, Z=150, surface="Formacao_3", pole_vector=(0,0,1))
# Out:
#         X      Y      Z  G_x  G_y  G_z  smooth     surface
# 0  1000.0  500.0  550.0  0.0  0.0  1.0    0.01  Formacao_2
# 1  1000.0  500.0  150.0  0.0  0.0  1.0    0.01  Formacao_3

# %%
# Ver os dados de surface points
#geo_model.surface_points

# Ver os dados de orientations points
geo_model.orientations

# %%
# Ver em 2D os dados nas 3 direções
gp.plot_2d(geo_model, direction=['x'], show_data=True)

gp.plot_2d(geo_model, direction=['y'], show_data=True)

gp.plot_2d(geo_model, direction=['z'], show_data=True)

# %%
# Ver o grid do modelo
geo_model.grid

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic', show_data=True)

# %%
# Adicionar uma topografia randômica 
geo_model.set_topography(source='random')
gp.plot_2d(geo_model, show_topography=True, section_names=['topography'])
plt.show()

# %%
# Interpolador
gp.set_interpolator(geo_model,
                    compile_theano=True,
                    theano_optimizer='fast_compile',
                    )
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                      values
# range              4657.25
# $C_o$            516428.57
# drift equations  [3, 3, 3]

# %%
# Computar a solução do modelo
sol = gp.compute_model(geo_model)
sol
# Out:
# Lithology ids
#   [5.         5.         5.         5.         5.         5.
#  5.         5.         4.         2.         5.         5.
#  5.         5.         5.         5.         5.         4.
#  3.         2.         5.         5.         5.         5.
#  5.         5.         4.         3.         2.         1.
#  3.         2.         1.98589737 1.         1.         1.
#  4.         3.         3.         2.         2.         1.
#  1.         1.         1.         1.         4.         4.
#  3.         3.         2.         2.         1.         1.
#  1.         1.         5.         4.         3.         3.
#  2.15570278 2.         1.         1.         1.         1.
#  5.         5.         5.         4.         3.         3.
#  3.         2.         1.         1.         5.         5.
#  5.         5.         5.         5.         4.         3.
#  2.         1.         5.         5.         5.         5.
#  5.         5.         5.         5.         4.         2.
#  5.         5.         5.         5.         5.         5.
#  5.         5.         4.         2.         5.         5.
#  5.         5.         5.         5.         5.         4.
#  3.         1.         5.         5.         5.         5.
#  5.         4.         3.         2.         1.         1.
#  5.         5.         4.         3.         3.         2.
#  2.         1.         1.         1.         4.         3.
#  3.         3.         2.         2.         1.         1.
#  1.         1.         4.         4.         3.         3.
#  2.         2.         1.         1.         1.         1.
#  5.         4.         4.         3.         3.         2.
#  2.         1.         1.         1.         5.         5.
#  5.         4.         3.         3.         3.         2.
#  1.         1.         5.         5.         5.         5.
#  5.         5.         4.         3.         2.00000001 1.
#  5.         5.         5.         5.         5.         5.
#  5.         5.         4.         2.         5.         5.
#  5.         5.         5.         5.         5.         5.
#  4.         2.         5.         5.         5.         5.
#  5.         5.         5.         4.         3.         1.
#  5.         5.         5.         5.         5.         4.
#  3.         3.         2.         1.         5.         5.
#  4.         3.         3.         3.         2.         1.
#  1.         1.         4.         3.99999708 3.         3.
#  2.         2.         1.         1.         1.         1.
#  4.         4.         3.         3.         2.         2.
#  1.         1.         1.         1.         5.         5.
#  4.         3.         3.         2.         2.         1.
#  1.         1.         5.         5.         5.         5.
#  4.         3.         3.         2.         1.         1.
#  5.         5.         5.         5.         5.         5.
#  5.         3.         3.         1.         5.         5.
#  5.         5.         5.         5.         5.         5.
#  4.         2.         5.         5.         5.         5.
#  5.         5.         5.         5.         4.         2.
#  5.         5.         5.         5.         5.         5.
#  5.         4.         3.         2.         5.         5.
#  5.         5.         5.         4.         3.         3.
#  2.         1.         5.         5.         4.         4.
#  3.         3.         2.         2.         1.         1.
#  4.         4.         3.         3.         2.         2.
#  2.         1.         1.         1.         4.         4.
#  3.         3.         3.         2.         2.         1.
#  1.         1.         5.         5.         4.         3.
#  3.         3.         2.         2.         1.         1.
#  5.         5.         5.         5.         5.         4.
#  3.         3.         2.         1.         5.         5.
#  5.         5.         5.         5.         5.         4.
#  3.         1.         5.         5.         5.         5.
#  5.         5.         5.         5.         4.         2.
#  5.         5.         5.         5.         5.         5.
#  5.         5.         4.         2.         5.         5.
#  5.         5.         5.         5.         5.         4.
#  3.         2.         5.         5.         5.         5.
#  5.         5.         4.         3.         2.         1.
#  5.         5.         5.         4.         4.         3.
#  3.         2.         2.         1.         5.         4.
#  4.         3.         3.         3.         2.         2.
#  1.         1.         5.         4.         4.         3.
#  3.         3.         2.         2.         1.         1.
#  5.         5.         5.         4.         4.         3.
#  3.         2.         2.         1.         5.         5.
#  5.         5.         5.         4.         3.         3.
#  2.         1.         5.         5.         5.         5.
#  5.         5.         5.         4.         3.         2.
#  5.         5.         5.         5.         5.         5.
#  5.         5.         4.         2.        ]

# %%
gp.plot_2d(geo_model, show_data=True)
plt.show()

# %%
ver, sim = gp.get_surfaces(geo_model)
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic')

# %%
g3d = gp.plot_3d(geo_model,
                 show_topography=True,
                 show_lith=False,
                 show_surfaces=True,
                 show_results=True)
