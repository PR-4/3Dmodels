# %%
# Importing dependency
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

pd.set_option('precision', 2)

# Data path, creating the model object and the name
data_path = '../../../input/Santos_Basin/Santos_Basin_114ma_seismic/v4/'
geo_model = gp.create_model('LakePreSal_CFF')
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# Extension of the model, resolution of the model and the paths of surface and orientation
gp.init_data(geo_model,
             extent=[0, 4000, 13750, 40000, -10000, 0],
             resolution=[50, 50, 50],
             path_i=data_path + "surfaces_points.csv",
             path_o=data_path + "orientations_points.csv")
# Out:
# Active grids: ['regular']
# LakePreSal_CFF  2023-06-27 14:51

# %%
# The surfaces of the model
gp.get_data(geo_model, 'surfaces')
# Out:
#     surface          series  order_surfaces    color  id
# 0   FALHA_1  Default series               1  #015482   1
# 1       UBV  Default series               2  #9f0052   2
# 2       LBV  Default series               3  #ffbe00   3
# 3   ITAPEMA  Default series               4  #728f02   4
# 4  CAMBORIU  Default series               5  #443988   5
# 5  basement        Basement               1  #ff3f20   6

# %%
# Sorting the surfaces and defining a serie for them (Stratigraphy - Top to Bottom)
gp.map_stack_to_surfaces(geo_model,                         
                         {"Fault_series": ('FALHA_1'),
                          "Strat_Series": ('UBV', 'LBV', 'ITAPEMA', 'CAMBORIU', 'basement')})

# Ver o grid do modelo
geo_model.grid
# Out:
# Grid Object. Values:
# array([[   40. , 14012.5, -9900. ],
#        [   40. , 14012.5, -9700. ],
#        [   40. , 14012.5, -9500. ],
#        ...,
#        [ 3960. , 39737.5,  -500. ],
#        [ 3960. , 39737.5,  -300. ],
#        [ 3960. , 39737.5,  -100. ]])

# %%
# Declaring the fault serie
geo_model.set_is_fault(['Fault_series'])
# Out:
# Fault colors changed. If you do not like this behavior, set change_color to False.
#               order_series BottomRelation  isActive  isFault  isFinite
# Fault_series             1          Fault      True     True     False
# Strat_Series             2        Erosion      True    False     False

# %%
geo_model.surfaces

# %%
# Plot 2D of the data in X, Y and Z direction
gp.plot_2d(geo_model, direction=['x'], show_data=True, show_boundaries=True, legend=False, show=True)

#gp.plot_2d(geo_model, direction=['y'], show_data=True, show_boundaries=True, legend=False, show=True)

#gp.plot_2d(geo_model, direction=['z'], show_data=True)

# %%
# Plot in 3D
gpv = gp.plot_3d(geo_model, plotter_type='basic', image=False, show_data=True, show_surfaces=True, show_scalar=True, show_boundaries=True)

# %%
# %%time
# Interpolating
gp.set_interpolator(geo_model,
                    theano_optimizer='fast_run',
                    compile_theano=True
                    )
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_run
# Device:  cpu
# Precision:  float64
# Number of faults:  1
# Compilation Done!
# Kriging values:
#                        values
# range               28373.62
# $C_o$            19168154.76
# drift equations       [3, 3]
# Wall time: 18.9 s

# %%
# %%time
# Computing a solution for the model
sol = gp.compute_model(geo_model, compute_mesh=True)
# Out:
# Wall time: 6.45 s

# %%
# Plot 2D of Y and X
#gp.plot_2d(geo_model, direction="y", show_data=False, show_lith=True)
gp.plot_2d(geo_model, direction="x", show_data=False, show_lith=True, show_boundaries=False)

# %%
# Plot 3D
ver, sim = gp.get_surfaces(geo_model)
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic', show_data=False, show_results=True, show_lith=False, show_boundaries=False)

# %%
# Saving the model in a .zip file
'''
This code saves the model in a .zip file in 
the same folder that the .ipynb file is located
'''

#gp.save_model(geo_model, compress=True)

# %% [markdown]
# # TESTE 2

# %%
# Extension of the model, resolution of the model and the paths of surface and orientation
gp.init_data(geo_model,
             extent=[0, 4000, 13750, 40000, -10000, 0],
             resolution=[100, 200, 100],
             path_i=data_path + "surfaces_points.csv",
             path_o=data_path + "orientations_points.csv")

# Sorting the surfaces and defining a serie for them (Stratigraphy - Top to Bottom)
gp.map_stack_to_surfaces(geo_model,                         
                         {"Fault_series": ('FALHA_1'),
                          "Strat_Series": ('UBV', 'LBV', 'ITAPEMA', 'CAMBORIU', 'basement')})

# Declaring the fault serie
geo_model.set_is_fault(['Fault_series'])
# Out:
# Active grids: ['regular']
# Fault colors changed. If you do not like this behavior, set change_color to False.
#               order_series BottomRelation  isActive  isFault  isFinite
# Fault_series             1          Fault      True     True     False
# Strat_Series             2        Erosion      True    False     False

# %%
# Plot 2D of the data in X, Y and Z direction
gp.plot_2d(geo_model, direction=['x', 'y'], 
           cell_number=[50, 100], show_data=True, 
           show_boundaries=True, legend=False, show=True)

#gp.plot_2d(geo_model, direction=['y'], show_data=True, show_boundaries=True, legend=False, show=True)

#gp.plot_2d(geo_model, direction=['z'], show_data=True)

# %%
# %%time
# Interpolating
gp.set_interpolator(geo_model,
                    theano_optimizer='fast_run',
                    compile_theano=True
                    )

# Computing a solution for the model
sol = gp.compute_model(geo_model, compute_mesh=True)
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_run
# Device:  cpu
# Precision:  float64
# Number of faults:  1
# Compilation Done!
# Kriging values:
#                        values
# range               28373.62
# $C_o$            19168154.76
# drift equations       [3, 3]
# Wall time: 1min 54s

# %%
# Plot 2D of Y and X
#gp.plot_2d(geo_model, direction="y", show_data=False, show_lith=True, show_boundaries=False)
gp.plot_2d(geo_model, direction="x", show_data=True, show_lith=True, show_boundaries=False)

# %%
# Plot 3D
ver, sim = gp.get_surfaces(geo_model)
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic', show_data=False, show_results=True, show_lith=False, show_boundaries=False)

# %% [markdown]
# # Test 3

# %%
# Extension of the model, resolution of the model and the paths of surface and orientation
gp.init_data(geo_model,
             extent=[0, 4000, 13750, 40000, -10000, 0],
             resolution=[100, 200, 100],
             path_i=data_path + "surfaces_points.csv",
             path_o=data_path + "orientations_points_2.csv")

# Sorting the surfaces and defining a serie for them (Stratigraphy - Top to Bottom)
gp.map_stack_to_surfaces(geo_model,                         
                         {"Fault_series": ('FALHA_1'),
                          "Strat_Series": ('UBV', 'LBV', 'ITAPEMA', 'CAMBORIU', 'basement')})

# Declaring the fault serie
geo_model.set_is_fault(['Fault_series'])
# Out:
# Active grids: ['regular']
# Fault colors changed. If you do not like this behavior, set change_color to False.
#               order_series BottomRelation  isActive  isFault  isFinite
# Fault_series             1          Fault      True     True     False
# Strat_Series             2        Erosion      True    False     False

# %%
# Plot 2D of the data in X, Y and Z direction
gp.plot_2d(geo_model, direction=['x', 'y'], 
           cell_number=[50, 100], show_data=True, 
           show_boundaries=True, legend=False, show=True)

#gp.plot_2d(geo_model, direction=['y'], show_data=True, show_boundaries=True, legend=False, show=True)

#gp.plot_2d(geo_model, direction=['z'], show_data=True)

# %%
# %%time
# Interpolating
gp.set_interpolator(geo_model,
                    theano_optimizer='fast_run',
                    compile_theano=True
                    )

# Computing a solution for the model
sol = gp.compute_model(geo_model, compute_mesh=True)
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_run
# Device:  cpu
# Precision:  float64
# Number of faults:  1
# Compilation Done!
# Kriging values:
#                        values
# range               28373.62
# $C_o$            19168154.76
# drift equations       [3, 3]
# Wall time: 1min 52s

# %%
# Plot 2D of Y and X
#gp.plot_2d(geo_model, direction="y", show_data=False, show_lith=True, show_boundaries=False)
gp.plot_2d(geo_model, direction="x", show_data=False, show_lith=True, show_boundaries=False, legend=False)

# %%
# Plot 3D
ver, sim = gp.get_surfaces(geo_model)
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic', show_data=False, show_results=True, show_lith=True, show_boundaries=False)
