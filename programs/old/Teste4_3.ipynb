# %%
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
data_path = '../input/Teste4/'
geo_model = gp.create_model('SyntheitcBasinTeste4')

# %%
gp.init_data(geo_model,
             extent=[1500, 10000, 1500, 10000, -500, 2500],
             resolution=[50, 50, 50],
             path_i=data_path + "surface_points.csv",
             path_o=data_path + "orientations_points.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13688\2993348103.py in <module>
# ----> 1 gp.init_data(geo_model,
#       2              extent=[1500, 10000, 1500, 10000, -500, 2500],
#       3              resolution=[50, 50, 50],
#       4              path_i=data_path + "surface_points.csv",
#       5              path_o=data_path + "orientations_points.csv")
#
# NameError: name 'gp' is not defined

# %%
geo_model.surfaces
# Out:
#        surface          series  order_surfaces    color  id
# 0    sandstone  Default series               1  #015482   1
# 1    siltstone  Default series               2  #9f0052   2
# 2        shale  Default series               3  #ffbe00   3
# 3   sandstone2  Default series               4  #728f02   4
# 4   siltstone2  Default series               5  #443988   5
# 5       shale2  Default series               6  #ff3f20   6
# 6   sandstone3  Default series               7  #5DA629   7
# 7   siltstone3  Default series               8  #4878d0   8
# 8       shale3  Default series               9  #ee854a   9
# 9   sandstone4  Default series              10  #6acc64  10
# 10  siltstone4  Default series              11  #d65f5f  11
# 11      fault1  Default series              12  #956cb4  12
# 12      fault2  Default series              13  #8c613c  13
# 13      fault3  Default series              14  #dc7ec0  14
# 14    basement        Basement               1  #797979  15

# %%
gp.map_stack_to_surfaces(geo_model,
                          {"Sedimentary_Series": ('sandstone', 'siltstone', 'shale', 'sandstone2', 'siltstone2', 'shale2', 'sandstone3', 'siltstone3', 'shale3', 'sandstone4', 'siltstone4'), 
                           "Fault_Series_1": 'fault1',  
                           "Fault_Series_2": 'fault2', 
                           "Fault_Series_3": 'fault3'
                           })
# Out:
#        surface              series  order_surfaces    color  id
# 0    sandstone  Sedimentary_Series               1  #015482   1
# 1    siltstone  Sedimentary_Series               2  #9f0052   2
# 2        shale  Sedimentary_Series               3  #ffbe00   3
# 3   sandstone2  Sedimentary_Series               4  #728f02   4
# 4   siltstone2  Sedimentary_Series               5  #443988   5
# 5       shale2  Sedimentary_Series               6  #ff3f20   6
# 6   sandstone3  Sedimentary_Series               7  #5DA629   7
# 7   siltstone3  Sedimentary_Series               8  #4878d0   8
# 8       shale3  Sedimentary_Series               9  #ee854a   9
# 9   sandstone4  Sedimentary_Series              10  #6acc64  10
# 10  siltstone4  Sedimentary_Series              11  #d65f5f  11
# 11      fault1      Fault_Series_1               1  #956cb4  12
# 12      fault2      Fault_Series_2               1  #8c613c  13
# 13      fault3      Fault_Series_3               1  #dc7ec0  14
# ...

# %%
geo_model.surfaces
# Out:
#        surface              series  order_surfaces    color  id
# 0    sandstone  Sedimentary_Series               1  #015482   1
# 1    siltstone  Sedimentary_Series               2  #9f0052   2
# 2        shale  Sedimentary_Series               3  #ffbe00   3
# 3   sandstone2  Sedimentary_Series               4  #728f02   4
# 4   siltstone2  Sedimentary_Series               5  #443988   5
# 5       shale2  Sedimentary_Series               6  #ff3f20   6
# 6   sandstone3  Sedimentary_Series               7  #5DA629   7
# 7   siltstone3  Sedimentary_Series               8  #4878d0   8
# 8       shale3  Sedimentary_Series               9  #ee854a   9
# 9   sandstone4  Sedimentary_Series              10  #6acc64  10
# 10  siltstone4  Sedimentary_Series              11  #d65f5f  11
# 11      fault1      Fault_Series_1               1  #956cb4  12
# 12      fault2      Fault_Series_2               1  #8c613c  13
# 13      fault3      Fault_Series_3               1  #dc7ec0  14
# ...

# %%
geo_model.stack
# Out:
#                     order_series BottomRelation  isActive  isFault  isFinite
# Sedimentary_Series             1        Erosion     False    False     False
# Fault_Series_1                 2        Erosion     False    False     False
# Fault_Series_2                 3        Erosion     False    False     False
# Fault_Series_3                 4        Erosion     False    False     False
# Basement                       5        Erosion     False    False     False

# %%
geo_model.set_is_fault(['Fault_Series_1','Fault_Series_2','Fault_Series_3'])
# Out:
# Fault colors changed. If you do not like this behavior, set change_color to False.
#                     order_series BottomRelation  isActive  isFault  isFinite
# Sedimentary_Series             1        Erosion     False    False     False
# Fault_Series_1                 2          Fault     False     True     False
# Fault_Series_2                 3          Fault     False     True     False
# Fault_Series_3                 4          Fault     False     True     False
# Basement                       5        Erosion     False    False     False

# %%
geo_model.faults.faults_relations_df
# Out:
#                     Sedimentary_Series  Fault_Series_1  Fault_Series_2  \
# Sedimentary_Series               False           False           False
# Fault_Series_1                   False           False           False
# Fault_Series_2                   False           False           False
# Fault_Series_3                   False           False           False
# Basement                         False           False           False
#
#                     Fault_Series_3  Basement
# Sedimentary_Series           False     False
# Fault_Series_1               False      True
# Fault_Series_2               False      True
# Fault_Series_3               False      True
# Basement                     False     False

# %%
geo_model.grid
# Out:
# Grid Object. Values:
# array([[  40.,   50.,    5.],
#        [  40.,   50.,   15.],
#        [  40.,   50.,   25.],
#        ...,
#        [3960., 4950.,  475.],
#        [3960., 4950.,  485.],
#        [3960., 4950.,  495.]])

# %%
gp.get_data(geo_model, 'surface_points').head()
# Out:
#       X     Y    Z    smooth     surface
# 0  2775  4500  100  0.000002   sandstone
# 1  2600  4200  250  0.000002   siltstone
# 2  2900  3900  150  0.000002       shale
# 3  3150  3600  300  0.000002  sandstone2
# 4  3300  3300  250  0.000002  siltstone2

# %%
gp.get_data(geo_model, 'orientations')
# Out:
#        X     Y    Z       G_x           G_y       G_z  smooth     surface
# 0   2775  4500  100  0.612372  3.535534e-01  0.707107    0.01   sandstone
# 1   2600  4200  250 -0.750000  4.330127e-01 -0.500000    0.01   siltstone
# 2   2900  3900  150 -0.813798 -4.698463e-01  0.342020    0.01       shale
# 3   3150  3600  300  0.383022  6.634139e-01  0.642788    0.01  sandstone2
# 4   3300  3300  250 -0.642788  9.999606e-13 -0.766044    0.01  siltstone2
# 5   3500  3100  100  0.750000 -4.330127e-01  0.500000    0.01      shale2
# 6   2750  2750  100 -0.754407 -1.330222e-01 -0.642788    0.01  sandstone3
# 7   3200  3200  150 -0.866025  9.998409e-13  0.500000    0.01  siltstone3
# 8   3000  3000  200  0.163176  9.254166e-01 -0.342020    0.01      shale3
# 9   3400  3400  300  0.612372  6.123724e-01  0.500000    0.01  sandstone4
# 10  3500  3500  350 -0.642788  9.999606e-13 -0.766044    0.01  siltstone4
# 11  3000  3000    0  0.813798  4.698463e-01  0.342020    0.01      fault1
# ...

# %%
plot = gp.plot_2d(geo_model, show_lith=False, show_boundaries=False)
plt.show()
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()

# %%
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic')
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\pyvista\utilities\helpers.py:508: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   'Points is not a float type. This can cause issues when '

# %%
gp.set_interpolator(geo_model,
                    compile_theano=True,
                    theano_optimizer='fast_compile',
                    )
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  3
# Compilation Done!
# Kriging values:
#                            values
# range                6422.616289
# $C_o$              982142.857143
# drift equations  [3, 3, 3, 3, 3]

# %%
gp.get_data(geo_model, 'kriging')
# Out:
#                           values
# range                6422.616289
# $C_o$              982142.857143
# drift equations  [3, 3, 3, 3, 3]

# %%
gp.compute_model(geo_model)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~\anaconda3\envs\gempy\lib\site-packages\theano\compile\function_module.py in __call__(self, *args, **kwargs)
#     902             outputs =\
# --> 903                 self.fn() if output_subset is None else\
#     904                 self.fn(output_subset=output_subset)
#
# ~\anaconda3\envs\gempy\lib\site-packages\theano\scan_module\scan_op.py in rval(p, i, o, n, allow_gc)
#     962                  allow_gc=allow_gc):
# --> 963             r = p(n, [x[0] for x in i], o)
#     964             for o in node.outputs:
#
# ~\anaconda3\envs\gempy\lib\site-packages\theano\scan_module\scan_op.py in p(node, args, outs)
#     951                                                 outs,
# --> 952                                                 self, node)
#     953         except (ImportError, theano.gof.cmodule.MissingGXX):
#
# ...
