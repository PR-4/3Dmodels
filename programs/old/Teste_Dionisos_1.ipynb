# %%
# Importar dependências
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

pd.set_option('precision', 2)
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# Criando o objeto modelo e variável para indicar a pasta com os dados
data_path = '../input/Teste_Dionisos/'
geo_model = gp.create_model('BES_DIONISOS_MODEL')

# %%
# Inicializando os dados, a extensão e a resolução do modelo.
gp.init_data(geo_model,
             extent=[400000, 580000, 7600000, 7850000, -15000, 15000],
             resolution=[150, 250, 85],
             path_i=data_path + "surfaces_points_bes_dionisos.csv")
             #path_o=data_path + "8_lago_sintetico_ligando_camadas_outros_testes/orientations_points.csv")
# Out:
# Active grids: ['regular']
# BES_DIONISOS_MODEL  2023-03-20 11:25

# %%
# Ver a ordem das formações
geo_model.surfaces
# Out:
#     surface          series  order_surfaces    color  id
# 0       top  Default series               1  #015482   1
# 1       mid  Default series               2  #9f0052   2
# 2       bot  Default series               3  #ffbe00   3
# 3  basement        Basement               1  #728f02   4

# %%
# Ordenando as surfaces (Estratigrafia (topo para base))
#gp.map_stack_to_surfaces(geo_model,                         
#                         {"Strat_Series_1": ('Formacao_1'),
#                          "Strat_Series_2": ('Formacao_2')
#                          "Strat_Series_2": ('Formacao_3')
#                          "Strat_Series_2": ('Formacao_4')})
gp.map_stack_to_surfaces(geo_model,                         
                         {"TOP_series": ('top'),
                          "MID_series": ('mid'),
                          "BOT_series": ('bot'),
                          "BASE_series": ('basement')})
# Out:
#     surface       series  order_surfaces    color  id
# 0       top   TOP_series               1  #015482   1
# 1       mid   MID_series               1  #9f0052   2
# 2       bot   BOT_series               1  #ffbe00   3
# 3  basement  BASE_series               1  #728f02   4

# %%
#Criando dados de orientação (Caso não tenha um csv importando)
geo_model.add_orientations(X=522500, Y=7702500, Z=3297.275879, surface="mid", pole_vector=(0,0,1))
# Out:
#           X         Y        Z  G_x  G_y  G_z  smooth surface
# 0  522500.0  7.70e+06  3297.28  0.0  0.0  1.0    0.01     mid

# %%
# Ver os dados de surface points
#geo_model.surface_points

# Ver os dados de orientations points
geo_model.orientations

# %%
# Ver em 2D os dados nas 3 direções
gp.plot_2d(geo_model, direction=['x'], show_data=True)

gp.plot_2d(geo_model, direction=['y'], show_data=True)

gp.plot_2d(geo_model, direction=['z'], show_data=True)

# %%
# Ver o grid do modelo
geo_model.grid

# %%
# Ver os dados em 3D
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic', show_data=True)

# %%
# Adicionar uma topografia randômica 
geo_model.set_topography(source='random')
gp.plot_2d(geo_model, show_topography=True, section_names=['topography'])
plt.show()

# %%
# %%time
# Interpolador
gp.set_interpolator(geo_model,
                    theano_optimizer='fast_run',
                    compile_theano=True
                    )
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_run
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                          values
# range                309515.75
# $C_o$            2280952380.95
# drift equations   [3, 3, 3, 3]
# Wall time: 12.1 s

# %%
# %%time
# Computar a solução do modelo
sol = gp.compute_model(geo_model, compute_mesh=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# scan_perform.pyx in theano.scan_module.scan_perform.perform()
#
# ValueError: Input dimension mis-match. (input[0].shape[1] = 0, input[1].shape[1] = 380)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\theano\compile\function_module.py in __call__(self, *args, **kwargs)
#     902             outputs =\
# --> 903                 self.fn() if output_subset is None else\
#     904                 self.fn(output_subset=output_subset)
#
# c:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\theano\scan_module\scan_op.py in rval(p, i, o, n, allow_gc)
#     962                  allow_gc=allow_gc):
# --> 963             r = p(n, [x[0] for x in i], o)
# ...

# %%
# Seção transversal do modelo
gp.plot_2d(geo_model, direction="x", show_data=False, show_lith=True)
gp.plot_2d(geo_model, direction="y", show_data=False, show_lith=True)
gp.plot_2d(geo_model, direction="z", show_data=False, show_lith=True)

# %%
# Visualizar o modelo em 3D
ver, sim = gp.get_surfaces(geo_model)
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic', show_data=False)

# %%
# Salvar o modelo gerado em zip (contem todos os files relevantes para refazer o modelo)
gp.save_model(geo_model)
