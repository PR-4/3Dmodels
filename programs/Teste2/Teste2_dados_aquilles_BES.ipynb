# %%
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
data_path = '../input/Teste2/'
geo_model = gp.create_model('SyntheitcBasinTeste2')

# %%
gp.init_data(geo_model, [489000, 590000, 7700000, 7900000, 0, 15500], [20, 20, 20],
            path_i=data_path + "089_100_surfaces_points.csv",
            path_o=data_path + "orientations_points.csv")
# Out:
# Active grids: ['regular']
# SyntheitcBasinTeste2  2023-03-10 11:20

# %%
geo_model.surfaces
# Out:
#       surface          series  order_surfaces    color  id
# 0   TURONIANO  Default series               1  #015482   1
# 1  ALBIANOSUP  Default series               2  #9f0052   2
# 2    basement        Basement               1  #ffbe00   3

# %%
gp.get_data(geo_model, 'surface_points').head()
# Out:
#         X        Y            Z    smooth    surface
# 0  400000  7650000  3580.360840  0.000002  TURONIANO
# 1  400250  7650000  3607.511719  0.000002  TURONIANO
# 2  400500  7650000  3633.510010  0.000002  TURONIANO
# 3  400750  7650000  3658.924072  0.000002  TURONIANO
# 4  401000  7650000  3687.059570  0.000002  TURONIANO

# %%
gp.get_data(geo_model, 'orientations').head()
# Out:
#         X        Y      Z           G_x           G_y  G_z  smooth     surface
# 0  450000  7780000   3580  1.000000e-12  1.000000e-12  1.0    0.01   TURONIANO
# 1  540000  7850000  10007  1.000000e-12  1.000000e-12  1.0    0.01  ALBIANOSUP

# %%
geo_model.additional_data
# Out:
#                                                                    values
# Structure isLith                                                     True
#           isFault                                                   False
#           number faults                                                 0
#           number surfaces                                               2
#           number series                                                 2
#           number surfaces per series                               [2, 0]
#           len surfaces surface_points                    [433321, 433321]
#           len series surface_points                           [866642, 0]
#           len series orientations                                  [2, 0]
# Options   dtype                                                   float64
#           output                                                  geology
#           theano_optimizer                                   fast_compile
# ...

# %%
geo_model.surfaces
# Out:
#       surface          series  order_surfaces    color  id
# 0   TURONIANO  Default series               1  #015482   1
# 1  ALBIANOSUP  Default series               2  #9f0052   2
# 2    basement        Basement               1  #ffbe00   3

# %%
gp.map_stack_to_surfaces(geo_model, {"Strat_Series": ('TURONIANO', 'ALBIANOSUP')})
# Out:
#       surface        series  order_surfaces    color  id
# 0   TURONIANO  Strat_Series               1  #015482   1
# 1  ALBIANOSUP  Strat_Series               2  #9f0052   2
# 2    basement      Basement               1  #ffbe00   3

# %%
geo_model.stack
# Out:
#               order_series BottomRelation  isActive  isFault  isFinite
# Strat_Series             1        Erosion      True    False     False
# Basement                 2        Erosion     False    False     False

# %%
geo_model.grid
# Out:
# Grid Object. Values:
# array([[4.91525e+05, 7.70500e+06, 3.87500e+02],
#        [4.91525e+05, 7.70500e+06, 1.16250e+03],
#        [4.91525e+05, 7.70500e+06, 1.93750e+03],
#        ...,
#        [5.87475e+05, 7.89500e+06, 1.35625e+04],
#        [5.87475e+05, 7.89500e+06, 1.43375e+04],
#        [5.87475e+05, 7.89500e+06, 1.51125e+04]])

# %%
plot = gp.plot_2d(geo_model, show_lith=False, show_boundaries=False)
plt.show()
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic')
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\pyvista\utilities\helpers.py:508: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   'Points is not a float type. This can cause issues when '

# %%
gp.set_interpolator(geo_model,
                    compile_theano=True,
                    theano_optimizer='fast_compile',
                    )
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                              values
# range                224591.295468
# $C_o$            1200982142.857143
# drift equations             [3, 3]

# %%
# sol = gp.compute_model(geo_model) - acho que dá erro de memoria por ser muito grande
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# scan_perform.pyx in theano.scan_module.scan_perform.perform()
#
# MemoryError: alloc failed
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# ~\anaconda3\envs\gempy\lib\site-packages\theano\compile\function_module.py in __call__(self, *args, **kwargs)
#     902             outputs =\
# --> 903                 self.fn() if output_subset is None else\
#     904                 self.fn(output_subset=output_subset)
#
# ~\anaconda3\envs\gempy\lib\site-packages\theano\scan_module\scan_op.py in rval(p, i, o, n, allow_gc)
#     962                  allow_gc=allow_gc):
# --> 963             r = p(n, [x[0] for x in i], o)
#     964             for o in node.outputs:
#
# ...

# %%
gp.plot_2d(geo_model, show_data=True)
plt.show()
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
g3d = gp.plot_3d(geo_model,
                 show_topography=True,
                 show_lith=False,
                 show_surfaces=False,
                 show_results=False)
# Out:
# C:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\pyvista\utilities\helpers.py:508: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   'Points is not a float type. This can cause issues when '
