# %%
import gempy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
# Out:
# Not subsurface compatibility available
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
data_path = '../input/'
geo_model = gp.create_model('BES_DIONISOS')

# %%
gp.init_data(geo_model,
             extent=[402500, 577500, 7652500, 7802500, 0, 15000],
             resolution=[50, 50, 50],
             path_i=data_path + "Teste2/089_100_surfaces_points.csv")
# Out:
# Active grids: ['regular']
# BES_DIONISOS  2023-03-16 11:05

# %%
geo_model.surfaces
# Out:
#       surface          series  order_surfaces    color  id
# 0   TURONIANO  Default series               1  #015482   1
# 1  ALBIANOSUP  Default series               2  #9f0052   2
# 2    basement        Basement               1  #ffbe00   3

# %%
gp.map_stack_to_surfaces(geo_model,
                         {"Strat_Series": ('TURONIANO', 'ALBIANOSUP')})
# Out:
#       surface        series  order_surfaces    color  id
# 0   TURONIANO  Strat_Series               1  #015482   1
# 1  ALBIANOSUP  Strat_Series               2  #9f0052   2
# 2    basement      Basement               1  #ffbe00   3

# %%
geo_model.surfaces
# Out:
#       surface        series  order_surfaces    color  id
# 0   TURONIANO  Strat_Series               1  #015482   1
# 1  ALBIANOSUP  Strat_Series               2  #9f0052   2
# 2    basement      Basement               1  #ffbe00   3

# %%
geo_model.add_orientations(X=400000, Y=7780500, Z=475, surface='TURONIANO', pole_vector=(0,0,1))
geo_model.add_orientations(X=400000, Y=7782500, Z=474, surface='ALBIANOSUP', pole_vector=(0,0,1))
# Out:
#           X          Y      Z  G_x  G_y  G_z  smooth     surface
# 0  400000.0  7780500.0  475.0  0.0  0.0  1.0    0.01   TURONIANO
# 1  400000.0  7782500.0  474.0  0.0  0.0  1.0    0.01  ALBIANOSUP

# %%
geo_model.grid
# Out:
# Grid Object. Values:
# array([[4.0425e+05, 7.6540e+06, 1.5000e+02],
#        [4.0425e+05, 7.6540e+06, 4.5000e+02],
#        [4.0425e+05, 7.6540e+06, 7.5000e+02],
#        ...,
#        [5.7575e+05, 7.8010e+06, 1.4250e+04],
#        [5.7575e+05, 7.8010e+06, 1.4550e+04],
#        [5.7575e+05, 7.8010e+06, 1.4850e+04]])

# %%
plot = gp.plot_2d(geo_model, show_lith=False, show_boundaries=False)
plt.show()
# Out:
# c:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\gempy\plot\plot_api.py:261: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   p.fig.show()
# c:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
gpv = gp.plot_3d(geo_model, image=False, plotter_type='basic')
# Out:
# c:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\pyvista\utilities\helpers.py:508: UserWarning: Points is not a float type. This can cause issues when transforming or applying filters. Casting to ``np.float32``. Disable this by passing ``force_float=False``.
#   'Points is not a float type. This can cause issues when '

# %%
gp.set_interpolator(geo_model,
                    compile_theano=True,
                    theano_optimizer='fast_compile',
                    )
# Out:
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_compile
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                              values
# range                230976.189249
# $C_o$            1270238095.238095
# drift equations             [3, 3]

# %%
sol = gp.compute_model(geo_model)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# scan_perform.pyx in theano.scan_module.scan_perform.perform()
#
# MemoryError: alloc failed
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# c:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\theano\compile\function_module.py in __call__(self, *args, **kwargs)
#     902             outputs =\
# --> 903                 self.fn() if output_subset is None else\
#     904                 self.fn(output_subset=output_subset)
#
# c:\Users\BernardoPR4\anaconda3\envs\gempy\lib\site-packages\theano\scan_module\scan_op.py in rval(p, i, o, n, allow_gc)
#     962                  allow_gc=allow_gc):
# --> 963             r = p(n, [x[0] for x in i], o)
#     964             for o in node.outputs:
#
# ...
